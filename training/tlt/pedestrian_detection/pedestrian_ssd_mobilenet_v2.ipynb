# %% [markdown]
# #  Training a SSD MobileNet V2 for Pedestrian Detection with TLT
#
# This notebook shows how to train a SSD MobileNet V2 object detector for pedestrian detection with [Nvidia's Transfer Learning Toolkit](https://developer.nvidia.com/transfer-learning-toolkit).
# TLT is a useful tool for train classification and object detection models with various pretrained backbone. The trained models with TLT can be easily integrate and deploy to DeepStream.
# Note that this notebook and specs files are just a modification of examples that exist on the [TLT docker container](https://ngc.nvidia.com/catalog/containers/nvidia:tlt-streamanalytics).
#
# 0. [Set up env variables](#head-0)
# 1. [Prepare dataset and pre-trained model](#head-1) <br>
#     1.1 [Prepare tfrecords from kitti format dataset](#head-1-1) <br>
#     1.2 [Download pre-trained model](#head-1-2) <br>
# 2. [Provide training specification](#head-2)
# 3. [Run TLT training](#head-3)
# 4. [Evaluate trained models](#head-4)
# 5. [Prune trained models](#head-5)
# 6. [Retrain pruned models](#head-6)
# 7. [Evaluate retrained model](#head-7)
# 8. [Visualize inferences](#head-8)
# 9. [Deploy](#head-9)

# %% [markdown]
# ## 0. Set up env variables <a class="anchor" id="head-0"></a>

# %%
# Setting up env variables for cleaner command line commands.
print("Please replace the variable with your key.")
# %set_env KEY=[YOUR NGC API KEY]
# %set_env USER_EXPERIMENT_DIR=/experiment_dir/ped_ssd_mobilenet_v2
# %set_env DATASET_DIR=/experiment_dir/dataset
# %set_env SPECS_DIR=/repo/training/tlt/pedestrian_detection/specs
# %set_env TF_FORCE_GPU_ALLOW_GROWTH=true
# !mkdir -p $USER_EXPERIMENT_DIR
# Out:
# Please replace the variable with your key.
# env: KEY=MzYwbm5pcGpxdmRxMHA1cjN2cnJodGtrYXE6YTJmMjE4MWEtM2E0Ni00MzhkLWI2YTItOWU0YzQ2MzRlZTgy
# env: USER_EXPERIMENT_DIR=/experiment_dir/ped_ssd_mobilenet_v2
# env: DATASET_DIR=/experiment_dir/dataset
# env: SPECS_DIR=/repo/training/tlt/specs

# %% [markdown]
# ## 1. Prepare dataset and pre-trained model <a class="anchor" id="head-1"></a>

# %% [markdown]
# We will be using [Oxford Town Center Dataset](https://www.robots.ox.ac.uk/ActiveVision/Research/Projects/2009bbenfold_headpose/project.html) for training our pedestrian detection. First we will download the video file and annotatoin `csv` file with `download_towncenter_video_and_labels.sh` script and then create images and kitti format annotation files with `extract_images.py` and `extract_kitti_labels.py` scripts. note that TLT will not perform dynamic resizing in training time and every image should be resize to a certain size offline (for SSD detectord the width and height of images should be a multiply of 32). Also for training object detectors the annotations should be in KITTI format. for further information about creating KITTI format annotations checkout [TLT getting started guide](https://docs.nvidia.com/metropolis/TLT/tlt-getting-started-guide/index.html)

# %%
# Download Oxford Town Center Dataset video file and csv annotation file
# !bash ./download_towncenter_video_and_labels.sh
# Out:
# mkdir: cannot create directory ‘/experiment_dir/dataset’: File exists
# --2020-05-19 18:13:10--  http://www.robots.ox.ac.uk/ActiveVision/Research/Projects/2009bbenfold_headpose/Datasets/TownCentreXVID.avi
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 147486436 (141M) [video/x-msvideo]
# Saving to: ‘/experiment_dir/dataset/TownCentreXVID.avi’
#
# /experiment_dir/dat 100%[===================>] 140.65M  4.14MB/s    in 28s
#
# 2020-05-19 18:13:39 (5.05 MB/s) - ‘/experiment_dir/dataset/TownCentreXVID.avi’ saved [147486436/147486436]
#
# --2020-05-19 18:13:39--  https://www.robots.ox.ac.uk/ActiveVision/Research/Projects/2009bbenfold_headpose/Datasets/TownCentre-groundtruth.top
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5553300 (5.3M)
# Saving to: ‘/experiment_dir/dataset/TownCentre-groundtruth.top’
#
# /experiment_dir/dat 100%[===================>]   5.30M  2.60MB/s    in 2.0s
#
# 2020-05-19 18:13:42 (2.60 MB/s) - ‘/experiment_dir/dataset/TownCentre-groundtruth.top’ saved [5553300/5553300]

# %%
# Extract images from video, resize them and save in images directory 
# !python3 extract_images.py --video_path $DATASET_DIR/TownCentreXVID.avi --image_width 320 --image_height 320
# Out:
# ==================== Start Reading Video ! ====================
# frame number 4501 extracted

# %%
# Create KITTI annotation file and save in labels directory
# !python3 extract_kitti_labels.py --annotation_path $DATASET_DIR/TownCentre-groundtruth.top --image_width 320 --image_height 320
# Out:
# ==================== Start Preparing Annotations in Kitti Format ! ====================
# annotation number 4500 prepared

# %%
# verify
# !ls -lh $DATASET_DIR/
# Out:
# total 147M
# -rw-r--r-- 1 root root 5.3M May 19  2011 TownCentre-groundtruth.top
# -rw-r--r-- 1 root root 141M Oct 30  2011 TownCentreXVID.avi
# drwxr-xr-x 2 root root 120K May 19 18:22 images
# drwxr-xr-x 2 root root 116K May 19 18:24 labels

# %% [markdown]
# ### 1.1 Prepare tfrecords from kitti format dataset <a class="anchor" id="head-1-1"></a>
#
# * Update the tfrecords spec file to take in your kitti format dataset
# * Create the tfrecords using the tlt-dataset-convert
# * TFRecords only need to be generated once.

# %%
print("TFrecords conversion spec file for training")
# !cat $SPECS_DIR/ssd_tfrecords_towncenter_trainval.txt
# Out:
# TFrecords conversion spec file for training
# kitti_config {
#   root_directory_path: "/experiment_dir/dataset"
#   image_dir_name: "images"
#   label_dir_name: "labels"
#   image_extension: ".jpg"
#   partition_mode: "random"
#   num_partitions: 2
#   val_split: 14
#   num_shards: 10
# }
# image_directory_path: "/experiment_dir/dataset"

# %%
# Creating a new directory for the output tfrecords dump.
# !mkdir -p $USER_EXPERIMENT_DIR/tfrecords
#KITTI trainval
# !tlt-dataset-convert -d $SPECS_DIR/ssd_tfrecords_towncenter_trainval.txt \
                     -o $DATA_DOWNLOAD_DIR/tfrecords/
# Out:
# Using TensorFlow backend.
# 2020-05-19 18:42:56,212 - iva.detectnet_v2.dataio.build_converter - INFO - Instantiating a kitti converter
# 2020-05-19 18:42:56,213 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Creating output directory /tfrecords
# 2020-05-19 18:42:56,221 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Num images in
# Train: 3871	Val: 630
# 2020-05-19 18:42:56,221 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2020-05-19 18:42:56,222 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 0
# /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/dataio/kitti_converter_lib.py:266: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 2020-05-19 18:42:56,288 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 1
# 2020-05-19 18:42:56,351 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 2
# 2020-05-19 18:42:56,411 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 3
# 2020-05-19 18:42:56,473 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 4
# 2020-05-19 18:42:56,533 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 5
# 2020-05-19 18:42:56,594 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 6
# 2020-05-19 18:42:56,655 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 7
# 2020-05-19 18:42:56,717 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 8
# 2020-05-19 18:42:56,777 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 9
# 2020-05-19 18:42:56,840 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# pedestrian: 10088
#
# 2020-05-19 18:42:56,840 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 0
# 2020-05-19 18:42:57,216 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 1
# 2020-05-19 18:42:57,588 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 2
# 2020-05-19 18:42:57,963 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 3
# 2020-05-19 18:42:58,334 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 4
# 2020-05-19 18:42:58,712 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 5
# 2020-05-19 18:42:59,084 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 6
# 2020-05-19 18:42:59,456 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 7
# 2020-05-19 18:42:59,827 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 8
# 2020-05-19 18:43:00,250 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 9
# 2020-05-19 18:43:00,624 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# pedestrian: 61372
#
# 2020-05-19 18:43:00,624 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Cumulative object statistics
# 2020-05-19 18:43:00,624 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# pedestrian: 71460
#
# 2020-05-19 18:43:00,624 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Class map.
# Label in GT: Label in tfrecords file
# pedestrian: pedestrian
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2020-05-19 18:43:00,624 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Tfrecords generation complete.

# %%
# !ls -rlt $DATASET_DIR/tfrecords/
# Out:
# total 6956
# -rw-r--r-- 1 root root 101813 May 19 18:35 -fold-000-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root  99601 May 19 18:35 -fold-000-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root  97923 May 19 18:35 -fold-000-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 100609 May 19 18:35 -fold-000-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root  97446 May 19 18:35 -fold-000-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root  98696 May 19 18:35 -fold-000-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 100370 May 19 18:35 -fold-000-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root  99646 May 19 18:35 -fold-000-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root  99413 May 19 18:35 -fold-000-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 102227 May 19 18:35 -fold-000-of-002-shard-00009-of-00010
# -rw-r--r-- 1 root root 614676 May 19 18:35 -fold-001-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 606124 May 19 18:35 -fold-001-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 611828 May 19 18:35 -fold-001-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 603853 May 19 18:35 -fold-001-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root 621001 May 19 18:35 -fold-001-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 607765 May 19 18:35 -fold-001-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 606162 May 19 18:35 -fold-001-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 601353 May 19 18:35 -fold-001-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root 604796 May 19 18:35 -fold-001-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 612719 May 19 18:35 -fold-001-of-002-shard-00009-of-00010

# %% [markdown]
# ### 1.2 Download pre-trained model <a class="anchor" id="head-1-2"></a>

# %% [markdown]
# We will use NGC CLI to get the pre-trained models. For more details, go to [ngc.nvidia.com](ngc.nvidia.com) and click the SETUP on the navigation bar.

# %%
# !ngc registry model list nvidia/tlt_pretrained_object_detection:*
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | Versi | Accur | Epoch | Batch | GPU   | Memor | File  | Statu | Creat |
# | on    | acy   | s     | Size  | Model | y Foo | Size  | s     | ed    |
# |       |       |       |       |       | tprin |       |       | Date  |
# |       |       |       |       |       | t     |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | resne | 74.38 | 80    | 1     | V100  | 38.3  | 38.31 | UPLOA | Apr   |
# | t10   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 76.74 | 80    | 1     | V100  | 89.0  | 88.96 | UPLOA | Apr   |
# | t18   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 77.04 | 80    | 1     | V100  | 170.7 | 170.6 | UPLOA | Apr   |
# | t34   |       |       |       |       |       | 5 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 77.91 | 80    | 1     | V100  | 294.2 | 294.2 | UPLOA | Apr   |
# | t50   |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | resne | 69.87 | 80    | 1     | V100  | 576.3 | 576.3 | UPLOA | Apr   |
# | t101  |       |       |       |       |       | 3 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | vgg16 | 77.17 | 80    | 1     | V100  | 113.2 | 113.1 | UPLOA | Apr   |
# |       |       |       |       |       |       | 6 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | vgg19 | 77.56 | 80    | 1     | V100  | 153.7 | 153.7 | UPLOA | Apr   |
# |       |       |       |       |       |       | 2 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | darkn | 76.44 | 80    | 1     | V100  | 311.7 | 311.6 | UPLOA | Apr   |
# | et53  |       |       |       |       |       | 8 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | darkn | 77.52 | 80    | 1     | V100  | 152.8 | 152.8 | UPLOA | Apr   |
# | et19  |       |       |       |       |       | 2 MB  | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | mobil | 72.75 | 80    | 1     | V100  | 5.0   | 5.01  | UPLOA | Apr   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 29,   |
# | v2    |       |       |       |       |       |       | PLETE | 2020  |
# | squee | 65.13 | 80    | 1     | V100  | 6.5   | 6.46  | UPLOA | Apr   |
# | zenet |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | googl | 77.11 | 80    | 1     | V100  | 47.6  | 47.64 | UPLOA | Apr   |
# | enet  |       |       |       |       |       | MB    | D_COM | 29,   |
# |       |       |       |       |       |       |       | PLETE | 2020  |
# | mobil | 79.5  | 80    | 1     | V100  | 26.2  | 26.22 | UPLOA | Apr   |
# | enet_ |       |       |       |       |       | MB    | D_COM | 29,   |
# | v1    |       |       |       |       |       |       | PLETE | 2020  |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2/

# %%
# Pull pretrained model from NGC
# !ngc registry model download-version nvidia/tlt_pretrained_object_detection:mobilenet_v2 --dest $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2
# Out:
# Downloaded 4.3 MB in 2s, Download speed: 2.15 MB/s
# ----------------------------------------------------
# Transfer id: tlt_pretrained_object_detection_vmobilenet_v2 Download status: Completed.
# Downloaded local path: /experiment_dir/ped_ssd_mobilenet_v2/pretrained_mobilenet_v2/tlt_pretrained_object_detection_vmobilenet_v2
# Total files downloaded: 1
# Total downloaded size: 4.3 MB
# Started at: 2020-05-19 19:26:37.985342
# Completed at: 2020-05-19 19:26:39.988655
# Duration taken: 2s
# ----------------------------------------------------

# %%
print("Check that model is downloaded into dir.")
# !ls -lh $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2/tlt_pretrained_object_detection_vmobilenet_v2
# Out:
# Check that model is downloaded into dir.
# total 5.1M
# -rw------- 1 root root 5.1M May 19 19:26 mobilenet_v2.hdf5

# %% [markdown]
# ## 2. Provide training specification <a class="anchor" id="head-2"></a>
# * Tfrecords for the train datasets
#     * In order to use the newly generated tfrecords, update the dataset_config parameter in the spec file at `$SPECS_DIR/ssd_train_resnet18_kitti.txt`
#     * Update the fold number to use for evaluation. In case of random data split, please use fold 0 only
#     * For sequence wise you may use any fold generated from the dataset convert tool
# * Pre-trained models
# * Augmentation parameters for on the fly data augmentation
# * Other training (hyper-)parameters such as batch size, number of epochs, learning rate etc.

# %%
# !cat $SPECS_DIR/ped_ssd_mobilenet_v2_train.txt
# Out:
# random_seed: 42
# ssd_config {
#   aspect_ratios_global: "[1.0, 2.0, 0.5, 3.0, 1.0/3.0]"
#   scales: "[0.1, 0.24166667, 0.38333333, 0.525, 0.66666667, 0.80833333, 0.95]"
#   two_boxes_for_ar1: true
#   clip_boxes: false
#   loss_loc_weight: 1.0
#   focal_loss_alpha: 0.25
#   focal_loss_gamma: 2.0
#   variances: "[0.1, 0.1, 0.2, 0.2]"
#   arch: "mobilenet_v2"
#   freeze_bn: false
# }
# training_config {
#   batch_size_per_gpu: 16
#   num_epochs: 250
#   learning_rate {
#   soft_start_annealing_schedule {
#     min_learning_rate: 5e-5
#     max_learning_rate: 2e-2
#     soft_start: 0.15
#     annealing: 0.5
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3e-06
#   }
# }
# eval_config {
#   validation_period_during_training: 10
#   average_precision_mode: SAMPLE
#   batch_size: 32
#   matching_iou_threshold: 0.5
# }
# nms_config {
#   confidence_threshold: 0.01
#   clustering_iou_threshold: 0.6
#   top_k: 200
# }
# augmentation_config {
#   preprocessing {
#     output_image_width: 320
#     output_image_height: 320
#     output_image_channel: 3
#     crop_right: 320
#     crop_bottom: 320
#     min_bbox_width: 1.0
#     min_bbox_height: 1.0
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     vflip_probability: 0.0
#     zoom_min: 0.7
#     zoom_max: 1.8
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
# dataset_config {
#   data_sources: {
#     tfrecords_path: "/experiment_dir/dataset/tfrecords/-fold*"
#     image_directory_path: "/experiment_dir/dataset"
#   }
#   image_extension: "jpg"
#   target_class_mapping {
#       key: "pedestrian"
#       value: "pedestrian"
#   }
#
# validation_fold: 0
# }

# %% [markdown]
# ## 3. Run TLT training <a class="anchor" id="head-3"></a>
# * Provide the sample spec file and the output directory location for models
# * WARNING: training will take several hours or one day to complete

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_unpruned

# %%
print("To run with multigpu, please change --gpus based on the number of available GPUs in your machine.")
# !tlt-train ssd -e $SPECS_DIR/ped_ssd_mobilenet_v2_train.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
               -k $KEY \
               -m $USER_EXPERIMENT_DIR/pretrained_mobilenet_v2/tlt_pretrained_object_detection_vmobilenet_v2/mobilenet_v2.hdf5 \
               --gpus 1
# Out:
# To run with multigpu, please change --gpus based on the number of available GPUs in your machine.
# Using TensorFlow backend.
# 2020-05-19 19:32:00,398 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_train.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-05-19 19:32:18,256 [INFO] iva.ssd.scripts.train: Loading pretrained weights. This may take a while...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (16, 3, 320, 320)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (16, 3, 322, 322)    0           Input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (16, 32, 160, 160)   864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (16, 32, 160, 160)   128         conv1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (16, 32, 160, 160)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_pad (Ze (16, 32, 162, 162)   0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (16, 32, 160, 160)   288         expanded_conv_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_bn (Bat (16, 32, 160, 160)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_relu (ReLU)       (16, 32, 160, 160)   0           expanded_conv_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (16, 16, 160, 160)   512         expanded_conv_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project_bn (Batch (16, 16, 160, 160)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (16, 96, 160, 160)   1536        expanded_conv_project_bn[0][0]
# __________________________________________________________________________________________________
# block_1_expand_bn (BatchNormali (16, 96, 160, 160)   384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (16, 96, 160, 160)   0           block_1_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_pad (ZeroPadd (16, 96, 162, 162)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (16, 96, 80, 80)     864         block_1_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_bn (BatchNorm (16, 96, 80, 80)     384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_relu (ReLU)             (16, 96, 80, 80)     0           block_1_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (16, 24, 80, 80)     2304        block_1_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_bn (BatchNormal (16, 24, 80, 80)     96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (16, 144, 80, 80)    3456        block_1_project_bn[0][0]
# __________________________________________________________________________________________________
# block_2_expand_bn (BatchNormali (16, 144, 80, 80)    576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (16, 144, 80, 80)    0           block_2_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_pad (ZeroPadd (16, 144, 82, 82)    0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (16, 144, 80, 80)    1296        block_2_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_bn (BatchNorm (16, 144, 80, 80)    576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_relu (ReLU)             (16, 144, 80, 80)    0           block_2_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (16, 24, 80, 80)     3456        block_2_relu[0][0]
# __________________________________________________________________________________________________
# block_2_projected_inputs (Conv2 (16, 24, 80, 80)     576         block_1_project_bn[0][0]
# __________________________________________________________________________________________________
# block_2_project_bn (BatchNormal (16, 24, 80, 80)     96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (16, 24, 80, 80)     0           block_2_projected_inputs[0][0]
#                                                                  block_2_project_bn[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (16, 144, 80, 80)    3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_bn (BatchNormali (16, 144, 80, 80)    576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (16, 144, 80, 80)    0           block_3_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_pad (ZeroPadd (16, 144, 82, 82)    0           re_lu_4[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (16, 144, 40, 40)    1296        block_3_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_bn (BatchNorm (16, 144, 40, 40)    576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_relu (ReLU)             (16, 144, 40, 40)    0           block_3_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (16, 32, 40, 40)     4608        block_3_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_bn (BatchNormal (16, 32, 40, 40)     128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (16, 192, 40, 40)    6144        block_3_project_bn[0][0]
# __________________________________________________________________________________________________
# block_4_expand_bn (BatchNormali (16, 192, 40, 40)    768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (16, 192, 40, 40)    0           block_4_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_pad (ZeroPadd (16, 192, 42, 42)    0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (16, 192, 40, 40)    1728        block_4_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_bn (BatchNorm (16, 192, 40, 40)    768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_relu (ReLU)             (16, 192, 40, 40)    0           block_4_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (16, 32, 40, 40)     6144        block_4_relu[0][0]
# __________________________________________________________________________________________________
# block_4_projected_inputs (Conv2 (16, 32, 40, 40)     1024        block_3_project_bn[0][0]
# __________________________________________________________________________________________________
# block_4_project_bn (BatchNormal (16, 32, 40, 40)     128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (16, 32, 40, 40)     0           block_4_projected_inputs[0][0]
#                                                                  block_4_project_bn[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (16, 192, 40, 40)    6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_bn (BatchNormali (16, 192, 40, 40)    768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (16, 192, 40, 40)    0           block_5_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_pad (ZeroPadd (16, 192, 42, 42)    0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (16, 192, 40, 40)    1728        block_5_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_bn (BatchNorm (16, 192, 40, 40)    768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_relu (ReLU)             (16, 192, 40, 40)    0           block_5_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (16, 32, 40, 40)     6144        block_5_relu[0][0]
# __________________________________________________________________________________________________
# block_5_projected_inputs (Conv2 (16, 32, 40, 40)     1024        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_project_bn (BatchNormal (16, 32, 40, 40)     128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (16, 32, 40, 40)     0           block_5_projected_inputs[0][0]
#                                                                  block_5_project_bn[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (16, 192, 40, 40)    6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_bn (BatchNormali (16, 192, 40, 40)    768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (16, 192, 40, 40)    0           block_6_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_pad (ZeroPadd (16, 192, 42, 42)    0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (16, 192, 20, 20)    1728        block_6_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_bn (BatchNorm (16, 192, 20, 20)    768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_relu (ReLU)             (16, 192, 20, 20)    0           block_6_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (16, 64, 20, 20)     12288       block_6_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_bn (BatchNormal (16, 64, 20, 20)     256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (16, 384, 20, 20)    24576       block_6_project_bn[0][0]
# __________________________________________________________________________________________________
# block_7_expand_bn (BatchNormali (16, 384, 20, 20)    1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (16, 384, 20, 20)    0           block_7_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_pad (ZeroPadd (16, 384, 22, 22)    0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (16, 384, 20, 20)    3456        block_7_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_bn (BatchNorm (16, 384, 20, 20)    1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_relu (ReLU)             (16, 384, 20, 20)    0           block_7_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (16, 64, 20, 20)     24576       block_7_relu[0][0]
# __________________________________________________________________________________________________
# block_7_projected_inputs (Conv2 (16, 64, 20, 20)     4096        block_6_project_bn[0][0]
# __________________________________________________________________________________________________
# block_7_project_bn (BatchNormal (16, 64, 20, 20)     256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (16, 64, 20, 20)     0           block_7_projected_inputs[0][0]
#                                                                  block_7_project_bn[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (16, 384, 20, 20)    24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_bn (BatchNormali (16, 384, 20, 20)    1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (16, 384, 20, 20)    0           block_8_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_pad (ZeroPadd (16, 384, 22, 22)    0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (16, 384, 20, 20)    3456        block_8_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_bn (BatchNorm (16, 384, 20, 20)    1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_relu (ReLU)             (16, 384, 20, 20)    0           block_8_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (16, 64, 20, 20)     24576       block_8_relu[0][0]
# __________________________________________________________________________________________________
# block_8_projected_inputs (Conv2 (16, 64, 20, 20)     4096        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_project_bn (BatchNormal (16, 64, 20, 20)     256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (16, 64, 20, 20)     0           block_8_projected_inputs[0][0]
#                                                                  block_8_project_bn[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (16, 384, 20, 20)    24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_bn (BatchNormali (16, 384, 20, 20)    1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (16, 384, 20, 20)    0           block_9_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_pad (ZeroPadd (16, 384, 22, 22)    0           re_lu_10[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (16, 384, 20, 20)    3456        block_9_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_bn (BatchNorm (16, 384, 20, 20)    1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_relu (ReLU)             (16, 384, 20, 20)    0           block_9_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (16, 64, 20, 20)     24576       block_9_relu[0][0]
# __________________________________________________________________________________________________
# block_9_projected_inputs (Conv2 (16, 64, 20, 20)     4096        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_project_bn (BatchNormal (16, 64, 20, 20)     256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (16, 64, 20, 20)     0           block_9_projected_inputs[0][0]
#                                                                  block_9_project_bn[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (16, 384, 20, 20)    24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_bn (BatchNormal (16, 384, 20, 20)    1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (16, 384, 20, 20)    0           block_10_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_pad (ZeroPad (16, 384, 22, 22)    0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (16, 384, 20, 20)    3456        block_10_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_bn (BatchNor (16, 384, 20, 20)    1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_relu (ReLU)            (16, 384, 20, 20)    0           block_10_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (16, 96, 20, 20)     36864       block_10_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_bn (BatchNorma (16, 96, 20, 20)     384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (16, 576, 20, 20)    55296       block_10_project_bn[0][0]
# __________________________________________________________________________________________________
# block_11_expand_bn (BatchNormal (16, 576, 20, 20)    2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (16, 576, 20, 20)    0           block_11_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_pad (ZeroPad (16, 576, 22, 22)    0           re_lu_12[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (16, 576, 20, 20)    5184        block_11_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_bn (BatchNor (16, 576, 20, 20)    2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_relu (ReLU)            (16, 576, 20, 20)    0           block_11_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (16, 96, 20, 20)     55296       block_11_relu[0][0]
# __________________________________________________________________________________________________
# block_11_projected_inputs (Conv (16, 96, 20, 20)     9216        block_10_project_bn[0][0]
# __________________________________________________________________________________________________
# block_11_project_bn (BatchNorma (16, 96, 20, 20)     384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (16, 96, 20, 20)     0           block_11_projected_inputs[0][0]
#                                                                  block_11_project_bn[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (16, 576, 20, 20)    55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_bn (BatchNormal (16, 576, 20, 20)    2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (16, 576, 20, 20)    0           block_12_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_pad (ZeroPad (16, 576, 22, 22)    0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (16, 576, 20, 20)    5184        block_12_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_bn (BatchNor (16, 576, 20, 20)    2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_relu (ReLU)            (16, 576, 20, 20)    0           block_12_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (16, 96, 20, 20)     55296       block_12_relu[0][0]
# __________________________________________________________________________________________________
# block_12_projected_inputs (Conv (16, 96, 20, 20)     9216        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_project_bn (BatchNorma (16, 96, 20, 20)     384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (16, 96, 20, 20)     0           block_12_projected_inputs[0][0]
#                                                                  block_12_project_bn[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_0 (Conv (16, 64, 20, 20)     6208        block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_0 (ReLU (16, 64, 20, 20)     0           ssd_expand_block_1_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_1 (Conv (16, 128, 10, 10)    73728       ssd_expand_block_1_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_bn_1 (BatchN (16, 128, 10, 10)    512         ssd_expand_block_1_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_1 (ReLU (16, 128, 10, 10)    0           ssd_expand_block_1_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_0 (Conv (16, 64, 10, 10)     8256        ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_0 (ReLU (16, 64, 10, 10)     0           ssd_expand_block_2_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_1 (Conv (16, 128, 5, 5)      73728       ssd_expand_block_2_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_bn_1 (BatchN (16, 128, 5, 5)      512         ssd_expand_block_2_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_1 (ReLU (16, 128, 5, 5)      0           ssd_expand_block_2_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_0 (Conv (16, 64, 5, 5)       8256        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_0 (ReLU (16, 64, 5, 5)       0           ssd_expand_block_3_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_1 (Conv (16, 128, 3, 3)      73728       ssd_expand_block_3_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_bn_1 (BatchN (16, 128, 3, 3)      512         ssd_expand_block_3_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_1 (ReLU (16, 128, 3, 3)      0           ssd_expand_block_3_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_0 (Conv (16, 64, 3, 3)       8256        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_0 (ReLU (16, 64, 3, 3)       0           ssd_expand_block_4_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_1 (Conv (16, 128, 2, 2)      73728       ssd_expand_block_4_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_bn_1 (BatchN (16, 128, 2, 2)      512         ssd_expand_block_4_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_1 (ReLU (16, 128, 2, 2)      0           ssd_expand_block_4_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_0 (Conv2D)             (16, 6, 40, 40)      10374       re_lu_7[0][0]
# __________________________________________________________________________________________________
# ssd_conf_1 (Conv2D)             (16, 6, 20, 20)      5190        block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_conf_2 (Conv2D)             (16, 6, 10, 10)      6918        ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_3 (Conv2D)             (16, 6, 5, 5)        6918        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_4 (Conv2D)             (16, 6, 3, 3)        6918        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_5 (Conv2D)             (16, 6, 2, 2)        6918        ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# permute_13 (Permute)            (16, 40, 40, 6)      0           ssd_conf_0[0][0]
# __________________________________________________________________________________________________
# permute_15 (Permute)            (16, 20, 20, 6)      0           ssd_conf_1[0][0]
# __________________________________________________________________________________________________
# permute_17 (Permute)            (16, 10, 10, 6)      0           ssd_conf_2[0][0]
# __________________________________________________________________________________________________
# permute_19 (Permute)            (16, 5, 5, 6)        0           ssd_conf_3[0][0]
# __________________________________________________________________________________________________
# permute_21 (Permute)            (16, 3, 3, 6)        0           ssd_conf_4[0][0]
# __________________________________________________________________________________________________
# permute_23 (Permute)            (16, 2, 2, 6)        0           ssd_conf_5[0][0]
# __________________________________________________________________________________________________
# ssd_loc_0 (Conv2D)              (16, 24, 40, 40)     41496       re_lu_7[0][0]
# __________________________________________________________________________________________________
# ssd_loc_1 (Conv2D)              (16, 24, 20, 20)     20760       block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_loc_2 (Conv2D)              (16, 24, 10, 10)     27672       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_3 (Conv2D)              (16, 24, 5, 5)       27672       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_4 (Conv2D)              (16, 24, 3, 3)       27672       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_5 (Conv2D)              (16, 24, 2, 2)       27672       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# conf_reshape_0 (Reshape)        (16, 9600, 1, 1)     0           permute_13[0][0]
# __________________________________________________________________________________________________
# conf_reshape_1 (Reshape)        (16, 2400, 1, 1)     0           permute_15[0][0]
# __________________________________________________________________________________________________
# conf_reshape_2 (Reshape)        (16, 600, 1, 1)      0           permute_17[0][0]
# __________________________________________________________________________________________________
# conf_reshape_3 (Reshape)        (16, 150, 1, 1)      0           permute_19[0][0]
# __________________________________________________________________________________________________
# conf_reshape_4 (Reshape)        (16, 54, 1, 1)       0           permute_21[0][0]
# __________________________________________________________________________________________________
# conf_reshape_5 (Reshape)        (16, 24, 1, 1)       0           permute_23[0][0]
# __________________________________________________________________________________________________
# permute_14 (Permute)            (16, 40, 40, 24)     0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (16, 20, 20, 24)     0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# permute_18 (Permute)            (16, 10, 10, 24)     0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# permute_20 (Permute)            (16, 5, 5, 24)       0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# permute_22 (Permute)            (16, 3, 3, 24)       0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# permute_24 (Permute)            (16, 2, 2, 24)       0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_0 (AnchorBoxes)      (16, 1600, 6, 8)     0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_1 (AnchorBoxes)      (16, 400, 6, 8)      0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_2 (AnchorBoxes)      (16, 100, 6, 8)      0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_3 (AnchorBoxes)      (16, 25, 6, 8)       0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_4 (AnchorBoxes)      (16, 9, 6, 8)        0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_5 (AnchorBoxes)      (16, 4, 6, 8)        0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (16, 12828, 1, 1)    0           conf_reshape_0[0][0]
#                                                                  conf_reshape_1[0][0]
#                                                                  conf_reshape_2[0][0]
#                                                                  conf_reshape_3[0][0]
#                                                                  conf_reshape_4[0][0]
#                                                                  conf_reshape_5[0][0]
# __________________________________________________________________________________________________
# loc_reshape_0 (Reshape)         (16, 9600, 1, 4)     0           permute_14[0][0]
# __________________________________________________________________________________________________
# loc_reshape_1 (Reshape)         (16, 2400, 1, 4)     0           permute_16[0][0]
# __________________________________________________________________________________________________
# loc_reshape_2 (Reshape)         (16, 600, 1, 4)      0           permute_18[0][0]
# __________________________________________________________________________________________________
# loc_reshape_3 (Reshape)         (16, 150, 1, 4)      0           permute_20[0][0]
# __________________________________________________________________________________________________
# loc_reshape_4 (Reshape)         (16, 54, 1, 4)       0           permute_22[0][0]
# __________________________________________________________________________________________________
# loc_reshape_5 (Reshape)         (16, 24, 1, 4)       0           permute_24[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_0 (Reshape)      (16, 9600, 1, 8)     0           ssd_anchor_0[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_1 (Reshape)      (16, 2400, 1, 8)     0           ssd_anchor_1[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_2 (Reshape)      (16, 600, 1, 8)      0           ssd_anchor_2[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_3 (Reshape)      (16, 150, 1, 8)      0           ssd_anchor_3[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_4 (Reshape)      (16, 54, 1, 8)       0           ssd_anchor_4[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_5 (Reshape)      (16, 24, 1, 8)       0           ssd_anchor_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf_sigmoid (Activation)  (16, 12828, 1, 1)    0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (16, 12828, 1, 4)    0           loc_reshape_0[0][0]
#                                                                  loc_reshape_1[0][0]
#                                                                  loc_reshape_2[0][0]
#                                                                  loc_reshape_3[0][0]
#                                                                  loc_reshape_4[0][0]
#                                                                  loc_reshape_5[0][0]
# __________________________________________________________________________________________________
# ...
# Epoch 4/250
# 242/242 [==============================] - 53s 218ms/step - loss: 3.6337
#
# Epoch 00004: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_004.tlt
# Epoch 5/250
# 242/242 [==============================] - 53s 218ms/step - loss: 3.4095
#
# Epoch 00005: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_005.tlt
# Epoch 6/250
# 242/242 [==============================] - 53s 219ms/step - loss: 3.1862
#
# Epoch 00006: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_006.tlt
# Epoch 7/250
# 242/242 [==============================] - 53s 219ms/step - loss: 3.0102
#
# Epoch 00007: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_007.tlt
# Epoch 8/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.8810
#
# Epoch 00008: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_008.tlt
# Epoch 9/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.7496
#
# Epoch 00009: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_009.tlt
# Epoch 10/250
# 242/242 [==============================] - 53s 220ms/step - loss: 2.6414
#
# Epoch 00010: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_010.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:10<00:00,  1.95it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.468
#               mAP   0.468
# *******************************
# Epoch 11/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.5447
#
# Epoch 00011: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_011.tlt
# Epoch 12/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.4257
#
# Epoch 00012: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_012.tlt
# Epoch 13/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.3552
#
# Epoch 00013: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_013.tlt
# Epoch 14/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.2595
#
# Epoch 00014: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_014.tlt
# Epoch 15/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.1637
#
# Epoch 00015: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_015.tlt
# Epoch 16/250
# 242/242 [==============================] - 53s 219ms/step - loss: 2.0833
#
# Epoch 00016: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_016.tlt
# Epoch 17/250
# 242/242 [==============================] - 53s 220ms/step - loss: 2.0231
#
# Epoch 00017: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_017.tlt
# Epoch 18/250
# 242/242 [==============================] - 53s 219ms/step - loss: 1.9489
#
# Epoch 00018: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_018.tlt
# Epoch 19/250
# 242/242 [==============================] - 53s 219ms/step - loss: 1.9020
#
# Epoch 00019: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_019.tlt
# Epoch 20/250
# 242/242 [==============================] - 53s 219ms/step - loss: 1.8167
#
# Epoch 00020: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_020.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.65it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.532
#               mAP   0.532
# *******************************
# Epoch 21/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.7716
#
# Epoch 00021: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_021.tlt
# Epoch 22/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.7364
#
# Epoch 00022: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_022.tlt
# Epoch 23/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.6908
#
# Epoch 00023: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_023.tlt
# Epoch 24/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.6135
#
# Epoch 00024: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_024.tlt
# Epoch 25/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.6019
#
# Epoch 00025: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_025.tlt
# Epoch 26/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.5278
#
# Epoch 00026: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_026.tlt
# Epoch 27/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.4928
#
# Epoch 00027: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_027.tlt
# Epoch 28/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.4358
#
# Epoch 00028: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_028.tlt
# Epoch 29/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.3650
#
# Epoch 00029: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_029.tlt
# Epoch 30/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.3240
#
# Epoch 00030: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_030.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.62it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.725
#               mAP   0.725
# *******************************
# Epoch 31/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.3246
#
# Epoch 00031: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_031.tlt
# Epoch 32/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.2657
#
# Epoch 00032: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_032.tlt
# Epoch 33/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.2361
#
# Epoch 00033: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_033.tlt
# Epoch 34/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.2003
#
# Epoch 00034: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_034.tlt
# Epoch 35/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.1791
#
# Epoch 00035: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_035.tlt
# Epoch 36/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.1553
#
# Epoch 00036: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_036.tlt
# Epoch 37/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.1364
#
# Epoch 00037: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_037.tlt
# Epoch 38/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.1238
#
# Epoch 00038: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_038.tlt
# Epoch 39/250
# 242/242 [==============================] - 53s 220ms/step - loss: 1.0869
#
# Epoch 00039: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_039.tlt
# Epoch 40/250
# 242/242 [==============================] - 53s 221ms/step - loss: 1.0487
#
# Epoch 00040: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_040.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.55it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.734
#               mAP   0.734
# *******************************
# Epoch 41/250
# 242/242 [==============================] - 54s 222ms/step - loss: 1.0416
#
# Epoch 00041: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_041.tlt
# Epoch 42/250
# 242/242 [==============================] - 54s 223ms/step - loss: 1.0098
#
# Epoch 00042: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_042.tlt
# Epoch 43/250
# 242/242 [==============================] - 54s 223ms/step - loss: 0.9953
#
# Epoch 00043: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_043.tlt
# Epoch 44/250
# 242/242 [==============================] - 53s 221ms/step - loss: 0.9842
#
# Epoch 00044: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_044.tlt
# Epoch 45/250
# 242/242 [==============================] - 54s 223ms/step - loss: 0.9731
#
# Epoch 00045: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_045.tlt
# Epoch 46/250
# 242/242 [==============================] - 54s 222ms/step - loss: 0.9725
#
# Epoch 00046: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_046.tlt
# Epoch 47/250
# 242/242 [==============================] - 54s 221ms/step - loss: 0.9505
#
# Epoch 00047: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_047.tlt
# Epoch 48/250
# 242/242 [==============================] - 54s 223ms/step - loss: 0.9369
#
# Epoch 00048: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_048.tlt
# Epoch 49/250
# 242/242 [==============================] - 53s 221ms/step - loss: 0.9322
#
# Epoch 00049: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_049.tlt
# Epoch 50/250
# 242/242 [==============================] - 54s 222ms/step - loss: 0.9196
#
# Epoch 00050: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_050.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:08<00:00,  2.49it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.72
#               mAP   0.72
# *******************************
# Epoch 51/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.9286
#
# Epoch 00051: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_051.tlt
# Epoch 52/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8987
#
# Epoch 00052: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_052.tlt
# Epoch 53/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8946
#
# Epoch 00053: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_053.tlt
# Epoch 54/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8856
#
# Epoch 00054: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_054.tlt
# Epoch 55/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8805
#
# Epoch 00055: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_055.tlt
# Epoch 56/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8787
#
# Epoch 00056: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_056.tlt
# Epoch 57/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8864
#
# Epoch 00057: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_057.tlt
# Epoch 58/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8695
#
# Epoch 00058: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_058.tlt
# Epoch 59/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8607
#
# Epoch 00059: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_059.tlt
# Epoch 60/250
# 242/242 [==============================] - 53s 219ms/step - loss: 0.8681
#
# Epoch 00060: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_060.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:08<00:00,  2.44it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.835
#               mAP   0.835
# *******************************
# Epoch 61/250
# 242/242 [==============================] - 53s 220ms/step - loss: 0.8607
#
# Epoch 00061: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_061.tlt
# Epoch 62/250
# 242/242 [==============================] - 53s 220ms/step - loss: 0.8512
#
# Epoch 00062: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_062.tlt
# Epoch 63/250
# 242/242 [==============================] - 53s 220ms/step - loss: 0.8328
#
# Epoch 00063: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_063.tlt
# Epoch 64/250
# 120/242 [=============>................] - ETA: 26s - loss: 0.8324^C
# Traceback (most recent call last):
#   File "/usr/local/bin/tlt-train-g1", line 8, in <module>
#     sys.exit(main())
#   File "./common/magnet_train.py", line 37, in main
#   File "./ssd/scripts/train.py", line 245, in main
#   File "./ssd/scripts/train.py", line 182, in run_experiment
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/training.py", line 1039, in fit
#     validation_steps=validation_steps)
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/training_arrays.py", line 154, in fit_loop
#     outs = f(ins)
#   File "/usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %%
print('Model for each epoch:')
print('---------------------')
# !ls -ltrh $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights
# Out:
# Model for each epoch:
# ---------------------
# total 306M
# -rw-r--r-- 1 root root 4.9M May 19 19:40 ssd_mobilenet_v2_epoch_001.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:40 ssd_mobilenet_v2_epoch_002.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:41 ssd_mobilenet_v2_epoch_003.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:42 ssd_mobilenet_v2_epoch_004.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:43 ssd_mobilenet_v2_epoch_005.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:44 ssd_mobilenet_v2_epoch_006.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:45 ssd_mobilenet_v2_epoch_007.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:46 ssd_mobilenet_v2_epoch_008.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:47 ssd_mobilenet_v2_epoch_009.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:48 ssd_mobilenet_v2_epoch_010.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:49 ssd_mobilenet_v2_epoch_011.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:50 ssd_mobilenet_v2_epoch_012.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:50 ssd_mobilenet_v2_epoch_013.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:51 ssd_mobilenet_v2_epoch_014.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:52 ssd_mobilenet_v2_epoch_015.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:53 ssd_mobilenet_v2_epoch_016.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:54 ssd_mobilenet_v2_epoch_017.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:55 ssd_mobilenet_v2_epoch_018.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:56 ssd_mobilenet_v2_epoch_019.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:57 ssd_mobilenet_v2_epoch_020.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:58 ssd_mobilenet_v2_epoch_021.tlt
# -rw-r--r-- 1 root root 4.9M May 19 19:59 ssd_mobilenet_v2_epoch_022.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:00 ssd_mobilenet_v2_epoch_023.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:00 ssd_mobilenet_v2_epoch_024.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:01 ssd_mobilenet_v2_epoch_025.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:02 ssd_mobilenet_v2_epoch_026.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:03 ssd_mobilenet_v2_epoch_027.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:04 ssd_mobilenet_v2_epoch_028.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:05 ssd_mobilenet_v2_epoch_029.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:06 ssd_mobilenet_v2_epoch_030.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:07 ssd_mobilenet_v2_epoch_031.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:08 ssd_mobilenet_v2_epoch_032.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:09 ssd_mobilenet_v2_epoch_033.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:10 ssd_mobilenet_v2_epoch_034.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:10 ssd_mobilenet_v2_epoch_035.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:11 ssd_mobilenet_v2_epoch_036.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:12 ssd_mobilenet_v2_epoch_037.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:13 ssd_mobilenet_v2_epoch_038.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:14 ssd_mobilenet_v2_epoch_039.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:15 ssd_mobilenet_v2_epoch_040.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:16 ssd_mobilenet_v2_epoch_041.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:17 ssd_mobilenet_v2_epoch_042.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:18 ssd_mobilenet_v2_epoch_043.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:19 ssd_mobilenet_v2_epoch_044.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:20 ssd_mobilenet_v2_epoch_045.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:20 ssd_mobilenet_v2_epoch_046.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:21 ssd_mobilenet_v2_epoch_047.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:22 ssd_mobilenet_v2_epoch_048.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:23 ssd_mobilenet_v2_epoch_049.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:24 ssd_mobilenet_v2_epoch_050.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:25 ssd_mobilenet_v2_epoch_051.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:26 ssd_mobilenet_v2_epoch_052.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:27 ssd_mobilenet_v2_epoch_053.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:28 ssd_mobilenet_v2_epoch_054.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:29 ssd_mobilenet_v2_epoch_055.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:30 ssd_mobilenet_v2_epoch_056.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:30 ssd_mobilenet_v2_epoch_057.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:31 ssd_mobilenet_v2_epoch_058.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:32 ssd_mobilenet_v2_epoch_059.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:33 ssd_mobilenet_v2_epoch_060.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:34 ssd_mobilenet_v2_epoch_061.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:35 ssd_mobilenet_v2_epoch_062.tlt
# -rw-r--r-- 1 root root 4.9M May 19 20:36 ssd_mobilenet_v2_epoch_063.tlt

# %%
# Now check the evaluation stats in the csv file and pick the model with highest eval accuracy.
# Note csv epoch number is 1 less than model file epoch. For example, epoch 79 in csv corresponds to _080.tlt
# !cat $USER_EXPERIMENT_DIR/experiment_dir_unpruned/ssd_training_log_mobilenet_v2.csv
# Out:
# epoch,AP_pedestrian,loss,mAP
# 0,nan,29.151781076242116,nan
# 1,nan,4.732228832796586,nan
# 2,nan,3.9978318549384757,nan
# 3,nan,3.633695398480439,nan
# 4,nan,3.4094583643369436,nan
# 5,nan,3.186211319994335,nan
# 6,nan,3.0101682272824375,nan
# 7,nan,2.881046282358406,nan
# 8,nan,2.7495777577408087,nan
# 9,0.46808480006105635,2.6413573962597807,0.46808480006105635
# 10,nan,2.544672029077514,nan
# 11,nan,2.425690327794099,nan
# 12,nan,2.355249636922001,nan
# 13,nan,2.259492479080011,nan
# 14,nan,2.1637178950073306,nan
# 15,nan,2.083284270664877,nan
# 16,nan,2.0230536978106852,nan
# 17,nan,1.9489101378385685,nan
# 18,nan,1.902017742149101,nan
# 19,0.5315798822524529,1.8167129789502168,0.5315798822524529
# 20,nan,1.7716186081082368,nan
# 21,nan,1.7364224535374602,nan
# 22,nan,1.690828354398081,nan
# 23,nan,1.6134801300104,nan
# 24,nan,1.6019375920295715,nan
# 25,nan,1.5278049865044838,nan
# 26,nan,1.492781793283037,nan
# 27,nan,1.435770722952756,nan
# 28,nan,1.3650080359671726,nan
# 29,0.7245272176440288,1.3239730473392266,0.7245272176440288
# 30,nan,1.3245953222936835,nan
# 31,nan,1.2656558638761852,nan
# 32,nan,1.2360858530545038,nan
# 33,nan,1.2003360196086001,nan
# 34,nan,1.1791111038736075,nan
# 35,nan,1.1552934809164568,nan
# 36,nan,1.1364495180362513,nan
# 37,nan,1.123814549327882,nan
# 38,nan,1.0869105266145438,nan
# 39,0.7335583629300095,1.0487061394147636,0.7335583629300095
# 40,nan,1.0415934245448468,nan
# 41,nan,1.0098044382146567,nan
# 42,nan,0.9952783885080952,nan
# 43,nan,0.9841652160341089,nan
# 44,nan,0.973085325118924,nan
# 45,nan,0.9724854413142874,nan
# 46,nan,0.9504585872011736,nan
# 47,nan,0.9368542285004923,nan
# 48,nan,0.9322184582879721,nan
# 49,0.7195388917963658,0.9195574916098729,0.7195388917963658
# 50,nan,0.928624416678405,nan
# 51,nan,0.8986902581758736,nan
# 52,nan,0.8946493425645119,nan
# 53,nan,0.8856183428409671,nan
# 54,nan,0.8805055051795707,nan
# 55,nan,0.8787381717981386,nan
# 56,nan,0.8864259448918429,nan
# 57,nan,0.869475272076189,nan
# 58,nan,0.8607440544061424,nan
# 59,0.8351195352773487,0.8680960230590883,0.8351195352773487
# 60,nan,0.8607416167732113,nan
# 61,nan,0.8511804837333269,nan
# 62,nan,0.8327831744162504,nan

# %%
# Set the epoch number which has best performance
# %set_env EPOCH=060
# Out:
# env: EPOCH=060

# %% [markdown]
# ## 4. Evaluate trained models <a class="anchor" id="head-4"></a>

# %%
# !tlt-evaluate ssd -e $SPECS_DIR/ped_ssd_mobilenet_v2_train.txt \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
                  -k $KEY
# Out:
# Using TensorFlow backend.
# 2020-05-19 20:41:18,198 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_train.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-05-19 20:41:31,289 [INFO] iva.ssd.scripts.evaluate: Number of images in the validation dataset:	   630
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.54it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.835
#               mAP   0.835
# *******************************

# %% [markdown]
# ## 5. Prune trained models <a class="anchor" id="head-5"></a>
# * Specify pre-trained model
# * Equalization criterion (`Only for resnets as they have element wise operations or MobileNets.`)
# * Threshold for pruning.
# * A key to save and load the model
# * Output directory to store the model
#
# Usually, you just need to adjust `-pth` (threshold) for accuracy and model size trade off. Higher `pth` gives you smaller model (and thus higher inference speed) but worse accuracy. The threshold value depends on the dataset and the model. `0.5` in the block below is just a start point. If the retrain accuracy is good, you can increase this value to get smaller models. Otherwise, lower this value to get better accuracy.

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_pruned

# %%
# !tlt-prune -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
           -o $USER_EXPERIMENT_DIR/experiment_dir_pruned/ssd_mobilenet_v2_pruned.tlt \
           -eq intersection \
           -pth 0.5 \
           -k $KEY
# Out:
# Using TensorFlow backend.
# 2020-05-19 20:42:36,690 [INFO] modulus.pruning.pruning: Exploring graph for retainable indices
# 2020-05-19 20:42:38,392 [INFO] modulus.pruning.pruning: Pruning model and appending pruned nodes to new graph
# 2020-05-19 20:43:54,413 [INFO] iva.common.magnet_prune: Pruning ratio (pruned model / original model): 0.626073393914

# %%
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_pruned/
# Out:
# total 3304
# -rw-r--r-- 1 root root 3380104 May 19 20:43 ssd_mobilenet_v2_pruned.tlt

# %% [markdown]
# ## 6. Retrain pruned models <a class="anchor" id="head-6"></a>
# * Model needs to be re-trained to bring back accuracy after pruning
# * Specify re-training specification
# * WARNING: training will take several hours or one day to complete

# %%
# Printing the retrain spec file. 
# Here we have updated the spec file to include the newly pruned model as a pretrained weights.
# !cat $SPECS_DIR/ped_ssd_mobilenet_v2_retrain.txt
# Out:
# random_seed: 42
# ssd_config {
#   aspect_ratios_global: "[1.0, 2.0, 0.5, 3.0, 1.0/3.0]"
#   scales: "[0.1, 0.24166667, 0.38333333, 0.525, 0.66666667, 0.80833333, 0.95]"
#   two_boxes_for_ar1: true
#   clip_boxes: false
#   loss_loc_weight: 1.0
#   focal_loss_alpha: 0.25
#   focal_loss_gamma: 2.0
#   variances: "[0.1, 0.1, 0.2, 0.2]"
#   arch: "mobilenet_v2"
#   freeze_bn: false
# }
# training_config {
#   batch_size_per_gpu: 16
#   num_epochs: 250
#   learning_rate {
#   soft_start_annealing_schedule {
#     min_learning_rate: 5e-5
#     max_learning_rate: 2e-2
#     soft_start: 0.1
#     annealing: 0.3
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3.00000002618e-09
#   }
# }
# eval_config {
#   validation_period_during_training: 10
#   average_precision_mode: SAMPLE
#   batch_size: 32
#   matching_iou_threshold: 0.5
# }
# nms_config {
#   confidence_threshold: 0.01
#   clustering_iou_threshold: 0.6
#   top_k: 200
# }
# augmentation_config {
#   preprocessing {
#     output_image_width: 320
#     output_image_height: 320
#     output_image_channel: 3
#     crop_right: 320
#     crop_bottom: 320
#     min_bbox_width: 1.0
#     min_bbox_height: 1.0
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     vflip_probability: 0.0
#     zoom_min: 0.7
#     zoom_max: 1.8
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
# dataset_config {
#   data_sources: {
#     tfrecords_path: "/experiment_dir/dataset/tfrecords/-fold*"
#     image_directory_path: "/experiment_dir/dataset/"
#   }
#   image_extension: "jpg"
#   target_class_mapping {
#       key: "pedestrian"
#       value: "pedestrian"
#   }
#
# validation_fold: 0
# }

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_retrain

# %%
# Retraining using the pruned model as pretrained weights 
# !tlt-train ssd --gpus 1 \
               -e $SPECS_DIR/ped_ssd_mobilenet_v2_retrain.txt \
               -r $USER_EXPERIMENT_DIR/experiment_dir_retrain \
               -m $USER_EXPERIMENT_DIR/experiment_dir_pruned/ssd_mobilenet_v2_pruned.tlt \
               -k $KEY
# Out:
# Using TensorFlow backend.
# 2020-05-19 20:51:52,224 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_retrain.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-05-19 20:52:09,827 [INFO] iva.ssd.scripts.train: Loading pretrained weights. This may take a while...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (16, 3, 320, 320)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (16, 3, 322, 322)    0           Input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (16, 16, 160, 160)   432         conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (16, 16, 160, 160)   64          conv1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (16, 16, 160, 160)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_pad (Ze (16, 16, 162, 162)   0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (16, 16, 160, 160)   144         expanded_conv_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_bn (Bat (16, 16, 160, 160)   64          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_relu (ReLU)       (16, 16, 160, 160)   0           expanded_conv_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (16, 16, 160, 160)   256         expanded_conv_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project_bn (Batch (16, 16, 160, 160)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (16, 48, 160, 160)   768         expanded_conv_project_bn[0][0]
# __________________________________________________________________________________________________
# block_1_expand_bn (BatchNormali (16, 48, 160, 160)   192         block_1_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (16, 48, 160, 160)   0           block_1_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_pad (ZeroPadd (16, 48, 162, 162)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (16, 48, 80, 80)     432         block_1_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_bn (BatchNorm (16, 48, 80, 80)     192         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_relu (ReLU)             (16, 48, 80, 80)     0           block_1_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (16, 24, 80, 80)     1152        block_1_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_bn (BatchNormal (16, 24, 80, 80)     96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (16, 72, 80, 80)     1728        block_1_project_bn[0][0]
# __________________________________________________________________________________________________
# block_2_expand_bn (BatchNormali (16, 72, 80, 80)     288         block_2_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (16, 72, 80, 80)     0           block_2_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_pad (ZeroPadd (16, 72, 82, 82)     0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (16, 72, 80, 80)     648         block_2_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_bn (BatchNorm (16, 72, 80, 80)     288         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_relu (ReLU)             (16, 72, 80, 80)     0           block_2_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (16, 24, 80, 80)     1728        block_2_relu[0][0]
# __________________________________________________________________________________________________
# block_2_projected_inputs (Conv2 (16, 24, 80, 80)     576         block_1_project_bn[0][0]
# __________________________________________________________________________________________________
# block_2_project_bn (BatchNormal (16, 24, 80, 80)     96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (16, 24, 80, 80)     0           block_2_projected_inputs[0][0]
#                                                                  block_2_project_bn[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (16, 80, 80, 80)     1920        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_bn (BatchNormali (16, 80, 80, 80)     320         block_3_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (16, 80, 80, 80)     0           block_3_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_pad (ZeroPadd (16, 80, 82, 82)     0           re_lu_4[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (16, 80, 40, 40)     720         block_3_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_bn (BatchNorm (16, 80, 40, 40)     320         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_relu (ReLU)             (16, 80, 40, 40)     0           block_3_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (16, 32, 40, 40)     2560        block_3_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_bn (BatchNormal (16, 32, 40, 40)     128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (16, 96, 40, 40)     3072        block_3_project_bn[0][0]
# __________________________________________________________________________________________________
# block_4_expand_bn (BatchNormali (16, 96, 40, 40)     384         block_4_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (16, 96, 40, 40)     0           block_4_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_pad (ZeroPadd (16, 96, 42, 42)     0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (16, 96, 40, 40)     864         block_4_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_bn (BatchNorm (16, 96, 40, 40)     384         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_relu (ReLU)             (16, 96, 40, 40)     0           block_4_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (16, 16, 40, 40)     1536        block_4_relu[0][0]
# __________________________________________________________________________________________________
# block_4_projected_inputs (Conv2 (16, 16, 40, 40)     512         block_3_project_bn[0][0]
# __________________________________________________________________________________________________
# block_4_project_bn (BatchNormal (16, 16, 40, 40)     64          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (16, 16, 40, 40)     0           block_4_projected_inputs[0][0]
#                                                                  block_4_project_bn[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (16, 72, 40, 40)     1152        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_bn (BatchNormali (16, 72, 40, 40)     288         block_5_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (16, 72, 40, 40)     0           block_5_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_pad (ZeroPadd (16, 72, 42, 42)     0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (16, 72, 40, 40)     648         block_5_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_bn (BatchNorm (16, 72, 40, 40)     288         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_relu (ReLU)             (16, 72, 40, 40)     0           block_5_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (16, 24, 40, 40)     1728        block_5_relu[0][0]
# __________________________________________________________________________________________________
# block_5_projected_inputs (Conv2 (16, 24, 40, 40)     384         block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_project_bn (BatchNormal (16, 24, 40, 40)     96          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (16, 24, 40, 40)     0           block_5_projected_inputs[0][0]
#                                                                  block_5_project_bn[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (16, 144, 40, 40)    3456        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_bn (BatchNormali (16, 144, 40, 40)    576         block_6_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (16, 144, 40, 40)    0           block_6_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_pad (ZeroPadd (16, 144, 42, 42)    0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (16, 144, 20, 20)    1296        block_6_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_bn (BatchNorm (16, 144, 20, 20)    576         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_relu (ReLU)             (16, 144, 20, 20)    0           block_6_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (16, 64, 20, 20)     9216        block_6_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_bn (BatchNormal (16, 64, 20, 20)     256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (16, 64, 20, 20)     4096        block_6_project_bn[0][0]
# __________________________________________________________________________________________________
# block_7_expand_bn (BatchNormali (16, 64, 20, 20)     256         block_7_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (16, 64, 20, 20)     0           block_7_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_pad (ZeroPadd (16, 64, 22, 22)     0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (16, 64, 20, 20)     576         block_7_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_bn (BatchNorm (16, 64, 20, 20)     256         block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_relu (ReLU)             (16, 64, 20, 20)     0           block_7_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (16, 32, 20, 20)     2048        block_7_relu[0][0]
# __________________________________________________________________________________________________
# block_7_projected_inputs (Conv2 (16, 32, 20, 20)     2048        block_6_project_bn[0][0]
# __________________________________________________________________________________________________
# block_7_project_bn (BatchNormal (16, 32, 20, 20)     128         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (16, 32, 20, 20)     0           block_7_projected_inputs[0][0]
#                                                                  block_7_project_bn[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (16, 136, 20, 20)    4352        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_bn (BatchNormali (16, 136, 20, 20)    544         block_8_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (16, 136, 20, 20)    0           block_8_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_pad (ZeroPadd (16, 136, 22, 22)    0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (16, 136, 20, 20)    1224        block_8_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_bn (BatchNorm (16, 136, 20, 20)    544         block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_relu (ReLU)             (16, 136, 20, 20)    0           block_8_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (16, 56, 20, 20)     7616        block_8_relu[0][0]
# __________________________________________________________________________________________________
# block_8_projected_inputs (Conv2 (16, 56, 20, 20)     1792        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_project_bn (BatchNormal (16, 56, 20, 20)     224         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (16, 56, 20, 20)     0           block_8_projected_inputs[0][0]
#                                                                  block_8_project_bn[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (16, 120, 20, 20)    6720        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_bn (BatchNormali (16, 120, 20, 20)    480         block_9_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (16, 120, 20, 20)    0           block_9_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_pad (ZeroPadd (16, 120, 22, 22)    0           re_lu_10[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (16, 120, 20, 20)    1080        block_9_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_bn (BatchNorm (16, 120, 20, 20)    480         block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_relu (ReLU)             (16, 120, 20, 20)    0           block_9_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (16, 64, 20, 20)     7680        block_9_relu[0][0]
# __________________________________________________________________________________________________
# block_9_projected_inputs (Conv2 (16, 64, 20, 20)     3584        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_project_bn (BatchNormal (16, 64, 20, 20)     256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (16, 64, 20, 20)     0           block_9_projected_inputs[0][0]
#                                                                  block_9_project_bn[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (16, 192, 20, 20)    12288       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_bn (BatchNormal (16, 192, 20, 20)    768         block_10_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (16, 192, 20, 20)    0           block_10_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_pad (ZeroPad (16, 192, 22, 22)    0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (16, 192, 20, 20)    1728        block_10_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_bn (BatchNor (16, 192, 20, 20)    768         block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_relu (ReLU)            (16, 192, 20, 20)    0           block_10_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (16, 96, 20, 20)     18432       block_10_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_bn (BatchNorma (16, 96, 20, 20)     384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (16, 120, 20, 20)    11520       block_10_project_bn[0][0]
# __________________________________________________________________________________________________
# block_11_expand_bn (BatchNormal (16, 120, 20, 20)    480         block_11_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (16, 120, 20, 20)    0           block_11_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_pad (ZeroPad (16, 120, 22, 22)    0           re_lu_12[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (16, 120, 20, 20)    1080        block_11_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_bn (BatchNor (16, 120, 20, 20)    480         block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_relu (ReLU)            (16, 120, 20, 20)    0           block_11_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (16, 88, 20, 20)     10560       block_11_relu[0][0]
# __________________________________________________________________________________________________
# block_11_projected_inputs (Conv (16, 88, 20, 20)     8448        block_10_project_bn[0][0]
# __________________________________________________________________________________________________
# block_11_project_bn (BatchNorma (16, 88, 20, 20)     352         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (16, 88, 20, 20)     0           block_11_projected_inputs[0][0]
#                                                                  block_11_project_bn[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (16, 80, 20, 20)     7040        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_bn (BatchNormal (16, 80, 20, 20)     320         block_12_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (16, 80, 20, 20)     0           block_12_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_pad (ZeroPad (16, 80, 22, 22)     0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (16, 80, 20, 20)     720         block_12_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_bn (BatchNor (16, 80, 20, 20)     320         block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_relu (ReLU)            (16, 80, 20, 20)     0           block_12_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (16, 96, 20, 20)     7680        block_12_relu[0][0]
# __________________________________________________________________________________________________
# block_12_projected_inputs (Conv (16, 96, 20, 20)     8448        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_project_bn (BatchNorma (16, 96, 20, 20)     384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (16, 96, 20, 20)     0           block_12_projected_inputs[0][0]
#                                                                  block_12_project_bn[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_0 (Conv (16, 64, 20, 20)     6208        block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_0 (ReLU (16, 64, 20, 20)     0           ssd_expand_block_1_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_1 (Conv (16, 128, 10, 10)    73728       ssd_expand_block_1_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_bn_1 (BatchN (16, 128, 10, 10)    512         ssd_expand_block_1_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_1 (ReLU (16, 128, 10, 10)    0           ssd_expand_block_1_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_0 (Conv (16, 64, 10, 10)     8256        ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_0 (ReLU (16, 64, 10, 10)     0           ssd_expand_block_2_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_1 (Conv (16, 128, 5, 5)      73728       ssd_expand_block_2_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_bn_1 (BatchN (16, 128, 5, 5)      512         ssd_expand_block_2_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_1 (ReLU (16, 128, 5, 5)      0           ssd_expand_block_2_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_0 (Conv (16, 64, 5, 5)       8256        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_0 (ReLU (16, 64, 5, 5)       0           ssd_expand_block_3_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_1 (Conv (16, 128, 3, 3)      73728       ssd_expand_block_3_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_bn_1 (BatchN (16, 128, 3, 3)      512         ssd_expand_block_3_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_1 (ReLU (16, 128, 3, 3)      0           ssd_expand_block_3_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_0 (Conv (16, 64, 3, 3)       8256        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_0 (ReLU (16, 64, 3, 3)       0           ssd_expand_block_4_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_1 (Conv (16, 128, 2, 2)      73728       ssd_expand_block_4_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_bn_1 (BatchN (16, 128, 2, 2)      512         ssd_expand_block_4_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_1 (ReLU (16, 128, 2, 2)      0           ssd_expand_block_4_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_0 (Conv2D)             (16, 6, 40, 40)      7782        re_lu_7[0][0]
# __________________________________________________________________________________________________
# ssd_conf_1 (Conv2D)             (16, 6, 20, 20)      5190        block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_conf_2 (Conv2D)             (16, 6, 10, 10)      6918        ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_3 (Conv2D)             (16, 6, 5, 5)        6918        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_4 (Conv2D)             (16, 6, 3, 3)        6918        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_5 (Conv2D)             (16, 6, 2, 2)        6918        ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# permute_25 (Permute)            (16, 40, 40, 6)      0           ssd_conf_0[0][0]
# __________________________________________________________________________________________________
# permute_27 (Permute)            (16, 20, 20, 6)      0           ssd_conf_1[0][0]
# __________________________________________________________________________________________________
# permute_29 (Permute)            (16, 10, 10, 6)      0           ssd_conf_2[0][0]
# __________________________________________________________________________________________________
# permute_31 (Permute)            (16, 5, 5, 6)        0           ssd_conf_3[0][0]
# __________________________________________________________________________________________________
# permute_33 (Permute)            (16, 3, 3, 6)        0           ssd_conf_4[0][0]
# __________________________________________________________________________________________________
# permute_35 (Permute)            (16, 2, 2, 6)        0           ssd_conf_5[0][0]
# __________________________________________________________________________________________________
# ssd_loc_0 (Conv2D)              (16, 24, 40, 40)     31128       re_lu_7[0][0]
# __________________________________________________________________________________________________
# ssd_loc_1 (Conv2D)              (16, 24, 20, 20)     20760       block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_loc_2 (Conv2D)              (16, 24, 10, 10)     27672       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_3 (Conv2D)              (16, 24, 5, 5)       27672       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_4 (Conv2D)              (16, 24, 3, 3)       27672       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_5 (Conv2D)              (16, 24, 2, 2)       27672       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# conf_reshape_0 (Reshape)        (16, 9600, 1, 1)     0           permute_25[0][0]
# __________________________________________________________________________________________________
# conf_reshape_1 (Reshape)        (16, 2400, 1, 1)     0           permute_27[0][0]
# __________________________________________________________________________________________________
# conf_reshape_2 (Reshape)        (16, 600, 1, 1)      0           permute_29[0][0]
# __________________________________________________________________________________________________
# conf_reshape_3 (Reshape)        (16, 150, 1, 1)      0           permute_31[0][0]
# __________________________________________________________________________________________________
# conf_reshape_4 (Reshape)        (16, 54, 1, 1)       0           permute_33[0][0]
# __________________________________________________________________________________________________
# conf_reshape_5 (Reshape)        (16, 24, 1, 1)       0           permute_35[0][0]
# __________________________________________________________________________________________________
# permute_26 (Permute)            (16, 40, 40, 24)     0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# permute_28 (Permute)            (16, 20, 20, 24)     0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# permute_30 (Permute)            (16, 10, 10, 24)     0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# permute_32 (Permute)            (16, 5, 5, 24)       0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# permute_34 (Permute)            (16, 3, 3, 24)       0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# permute_36 (Permute)            (16, 2, 2, 24)       0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_0 (AnchorBoxes)      (16, 1600, 6, 8)     0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_1 (AnchorBoxes)      (16, 400, 6, 8)      0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_2 (AnchorBoxes)      (16, 100, 6, 8)      0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_3 (AnchorBoxes)      (16, 25, 6, 8)       0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_4 (AnchorBoxes)      (16, 9, 6, 8)        0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_5 (AnchorBoxes)      (16, 4, 6, 8)        0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (16, 12828, 1, 1)    0           conf_reshape_0[0][0]
#                                                                  conf_reshape_1[0][0]
#                                                                  conf_reshape_2[0][0]
#                                                                  conf_reshape_3[0][0]
#                                                                  conf_reshape_4[0][0]
#                                                                  conf_reshape_5[0][0]
# __________________________________________________________________________________________________
# loc_reshape_0 (Reshape)         (16, 9600, 1, 4)     0           permute_26[0][0]
# __________________________________________________________________________________________________
# loc_reshape_1 (Reshape)         (16, 2400, 1, 4)     0           permute_28[0][0]
# __________________________________________________________________________________________________
# loc_reshape_2 (Reshape)         (16, 600, 1, 4)      0           permute_30[0][0]
# __________________________________________________________________________________________________
# loc_reshape_3 (Reshape)         (16, 150, 1, 4)      0           permute_32[0][0]
# __________________________________________________________________________________________________
# loc_reshape_4 (Reshape)         (16, 54, 1, 4)       0           permute_34[0][0]
# __________________________________________________________________________________________________
# loc_reshape_5 (Reshape)         (16, 24, 1, 4)       0           permute_36[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_0 (Reshape)      (16, 9600, 1, 8)     0           ssd_anchor_0[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_1 (Reshape)      (16, 2400, 1, 8)     0           ssd_anchor_1[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_2 (Reshape)      (16, 600, 1, 8)      0           ssd_anchor_2[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_3 (Reshape)      (16, 150, 1, 8)      0           ssd_anchor_3[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_4 (Reshape)      (16, 54, 1, 8)       0           ssd_anchor_4[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_5 (Reshape)      (16, 24, 1, 8)       0           ssd_anchor_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf_sigmoid (Activation)  (16, 12828, 1, 1)    0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (16, 12828, 1, 4)    0           loc_reshape_0[0][0]
#                                                                  loc_reshape_1[0][0]
#                                                                  loc_reshape_2[0][0]
#                                                                  loc_reshape_3[0][0]
#                                                                  loc_reshape_4[0][0]
#                                                                  loc_reshape_5[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (16, 12828, 1, 8)    0           anchor_reshape_0[0][0]
#                                                                  anchor_reshape_1[0][0]
#                                                                  anchor_reshape_2[0][0]
#                                                                  anchor_reshape_3[0][0]
#                                                                  anchor_reshape_4[0][0]
#                                                                  anchor_reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (16, 12828, 1, 13)   0           mbox_conf_sigmoid[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# ssd_predictions (Reshape)       (16, 12828, 13)      0           concatenate_3[0][0]
# ==================================================================================================
# Total params: 711,292
# Trainable params: 704,044
# Non-trainable params: 7,248
# __________________________________________________________________________________________________
# 2020-05-19 20:53:35,467 [INFO] iva.ssd.scripts.train: Number of images in the training dataset:	  3871
# 2020-05-19 20:53:35,467 [INFO] iva.ssd.scripts.train: Number of images in the validation dataset:	   630
# Epoch 1/250
# 242/242 [==============================] - 48s 198ms/step - loss: 3.5010
#
# Epoch 00001: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_001.tlt
# Epoch 2/250
# 242/242 [==============================] - 40s 164ms/step - loss: 2.3405
#
# Epoch 00002: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_002.tlt
# Epoch 3/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.9773
#
# Epoch 00003: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_003.tlt
# Epoch 4/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.7780
#
# Epoch 00004: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_004.tlt
# Epoch 5/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.6573
#
# Epoch 00005: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_005.tlt
# Epoch 6/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.5413
#
# Epoch 00006: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_006.tlt
# Epoch 7/250
# 242/242 [==============================] - 40s 164ms/step - loss: 1.4624
#
# Epoch 00007: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_007.tlt
# Epoch 8/250
# 242/242 [==============================] - 40s 164ms/step - loss: 1.3911
#
# Epoch 00008: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_008.tlt
# Epoch 9/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.3264
#
# Epoch 00009: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_009.tlt
# Epoch 10/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.2762
#
# Epoch 00010: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_010.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:09<00:00,  2.04it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.704
#               mAP   0.704
# *******************************
# Epoch 11/250
# 242/242 [==============================] - 40s 165ms/step - loss: 1.2274
#
# Epoch 00011: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_011.tlt
# Epoch 12/250
# 242/242 [==============================] - 40s 166ms/step - loss: 1.1759
#
# Epoch 00012: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_012.tlt
# Epoch 13/250
# 242/242 [==============================] - 40s 166ms/step - loss: 1.1459
#
# Epoch 00013: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_013.tlt
# Epoch 14/250
# 242/242 [==============================] - 40s 166ms/step - loss: 1.1024
#
# Epoch 00014: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_014.tlt
# Epoch 15/250
# 242/242 [==============================] - 40s 166ms/step - loss: 1.0665
#
# Epoch 00015: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_015.tlt
# Epoch 16/250
# 242/242 [==============================] - 40s 166ms/step - loss: 1.0442
#
# Epoch 00016: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_016.tlt
# Epoch 17/250
# 242/242 [==============================] - 40s 166ms/step - loss: 1.0141
#
# Epoch 00017: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_017.tlt
# Epoch 18/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.9848
#
# Epoch 00018: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_018.tlt
# Epoch 19/250
# 242/242 [==============================] - 40s 167ms/step - loss: 0.9718
#
# Epoch 00019: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_019.tlt
# Epoch 20/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.9413
#
# Epoch 00020: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_020.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.74it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.827
#               mAP   0.827
# *******************************
# Epoch 21/250
# 242/242 [==============================] - 40s 165ms/step - loss: 0.9314
#
# Epoch 00021: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_021.tlt
# Epoch 22/250
# 242/242 [==============================] - 40s 165ms/step - loss: 0.9356
#
# Epoch 00022: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_022.tlt
# Epoch 23/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.9222
#
# Epoch 00023: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_023.tlt
# Epoch 24/250
# 242/242 [==============================] - 40s 165ms/step - loss: 0.8997
#
# Epoch 00024: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_024.tlt
# Epoch 25/250
# 242/242 [==============================] - 40s 165ms/step - loss: 0.9257
#
# Epoch 00025: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_025.tlt
# Epoch 26/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.9028
#
# Epoch 00026: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_026.tlt
# Epoch 27/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8807
#
# Epoch 00027: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_027.tlt
# Epoch 28/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8576
#
# Epoch 00028: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_028.tlt
# Epoch 29/250
# 242/242 [==============================] - 40s 165ms/step - loss: 0.8590
#
# Epoch 00029: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_029.tlt
# Epoch 30/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8252
#
# Epoch 00030: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_030.tlt
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.68it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.808
#               mAP   0.808
# *******************************
# Epoch 31/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8364
#
# Epoch 00031: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_031.tlt
# Epoch 32/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8325
#
# Epoch 00032: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_032.tlt
# Epoch 33/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8115
#
# Epoch 00033: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_033.tlt
# Epoch 34/250
# 242/242 [==============================] - 40s 166ms/step - loss: 0.8104
#
# Epoch 00034: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_034.tlt
# Epoch 35/250
# 242/242 [==============================] - 40s 165ms/step - loss: 0.8012
#
# Epoch 00035: saving model to /experiment_dir/ped_ssd_mobilenet_v2/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_035.tlt
# Epoch 36/250
# 239/242 [============================>.] - ETA: 0s - loss: 0.7951^C
# Traceback (most recent call last):
#   File "/usr/local/bin/tlt-train-g1", line 8, in <module>
#     sys.exit(main())
#   File "./common/magnet_train.py", line 37, in main
#   File "./ssd/scripts/train.py", line 245, in main
#   File "./ssd/scripts/train.py", line 182, in run_experiment
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/training.py", line 1039, in fit
#     validation_steps=validation_steps)
#   File "/usr/local/lib/python2.7/dist-packages/keras/engine/training_arrays.py", line 154, in fit_loop
#     outs = f(ins)
#   File "/usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %%
# Listing the newly retrained model.
# !ls -rlht $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights
# Out:
# total 113M
# -rw-r--r-- 1 root root 3.3M May 19 20:55 ssd_mobilenet_v2_epoch_001.tlt
# -rw-r--r-- 1 root root 3.3M May 19 20:56 ssd_mobilenet_v2_epoch_002.tlt
# -rw-r--r-- 1 root root 3.3M May 19 20:57 ssd_mobilenet_v2_epoch_003.tlt
# -rw-r--r-- 1 root root 3.3M May 19 20:57 ssd_mobilenet_v2_epoch_004.tlt
# -rw-r--r-- 1 root root 3.3M May 19 20:58 ssd_mobilenet_v2_epoch_005.tlt
# -rw-r--r-- 1 root root 3.3M May 19 20:59 ssd_mobilenet_v2_epoch_006.tlt
# -rw-r--r-- 1 root root 3.3M May 19 20:59 ssd_mobilenet_v2_epoch_007.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:00 ssd_mobilenet_v2_epoch_008.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:01 ssd_mobilenet_v2_epoch_009.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:01 ssd_mobilenet_v2_epoch_010.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:02 ssd_mobilenet_v2_epoch_011.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:03 ssd_mobilenet_v2_epoch_012.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:04 ssd_mobilenet_v2_epoch_013.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:04 ssd_mobilenet_v2_epoch_014.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:05 ssd_mobilenet_v2_epoch_015.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:06 ssd_mobilenet_v2_epoch_016.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:06 ssd_mobilenet_v2_epoch_017.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:07 ssd_mobilenet_v2_epoch_018.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:08 ssd_mobilenet_v2_epoch_019.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:08 ssd_mobilenet_v2_epoch_020.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:09 ssd_mobilenet_v2_epoch_021.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:10 ssd_mobilenet_v2_epoch_022.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:11 ssd_mobilenet_v2_epoch_023.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:11 ssd_mobilenet_v2_epoch_024.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:12 ssd_mobilenet_v2_epoch_025.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:13 ssd_mobilenet_v2_epoch_026.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:13 ssd_mobilenet_v2_epoch_027.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:14 ssd_mobilenet_v2_epoch_028.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:15 ssd_mobilenet_v2_epoch_029.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:15 ssd_mobilenet_v2_epoch_030.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:16 ssd_mobilenet_v2_epoch_031.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:17 ssd_mobilenet_v2_epoch_032.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:18 ssd_mobilenet_v2_epoch_033.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:18 ssd_mobilenet_v2_epoch_034.tlt
# -rw-r--r-- 1 root root 3.3M May 19 21:19 ssd_mobilenet_v2_epoch_035.tlt

# %%
# Now check the evaluation stats in the csv file and pick the model with highest eval accuracy.
# Note csv epoch number is 1 less than model file epoch. For example, epoch 79 in csv corresponds to _080.tlt
# !cat $USER_EXPERIMENT_DIR/experiment_dir_retrain/ssd_training_log_mobilenet_v2.csv
# Out:
# epoch,AP_pedestrian,loss,mAP
# 0,nan,3.501000173820937,nan
# 1,nan,2.3405386357268028,nan
# 2,nan,1.977292493847776,nan
# 3,nan,1.7780364007989238,nan
# 4,nan,1.6573262800855084,nan
# 5,nan,1.541275331304093,nan
# 6,nan,1.4624475930347915,nan
# 7,nan,1.3910609207862665,nan
# 8,nan,1.3264317571624251,nan
# 9,0.7036460812941614,1.2761740531803163,0.7036460812941614
# 10,nan,1.2273993196566242,nan
# 11,nan,1.1758908146669056,nan
# 12,nan,1.1459300367792775,nan
# 13,nan,1.1024272949242395,nan
# 14,nan,1.0664668102894932,nan
# 15,nan,1.0441798548067898,nan
# 16,nan,1.0140624474888005,nan
# 17,nan,0.9848106279353465,nan
# 18,nan,0.9717602825854436,nan
# 19,0.8270038125627662,0.9412819612617335,0.8270038125627662
# 20,nan,0.9314426358573693,nan
# 21,nan,0.9355672218582847,nan
# 22,nan,0.9221566142129504,nan
# 23,nan,0.8996510412082199,nan
# 24,nan,0.9256754887005514,nan
# 25,nan,0.9027806690409164,nan
# 26,nan,0.8806802783130614,nan
# 27,nan,0.8575764190066945,nan
# 28,nan,0.8590192681501719,nan
# 29,0.8076743770636309,0.8252010185363864,0.8076743770636309
# 30,nan,0.8363978168195929,nan
# 31,nan,0.8325229220646472,nan
# 32,nan,0.8115132983065834,nan
# 33,nan,0.810389216527466,nan
# 34,nan,0.8011977389331691,nan

# %%
# Set the epoch number which has best performance
# %set_env EPOCH=035
# Out:
# env: EPOCH=035

# %% [markdown]
# ## 7. Evaluate retrained model <a class="anchor" id="head-7"></a>

# %%
# !tlt-evaluate ssd -e $SPECS_DIR/ped_ssd_mobilenet_v2_retrain.txt \
                  -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
                  -k $KEY
# Out:
# Using TensorFlow backend.
# 2020-05-19 21:21:50,958 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_retrain.txt
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-05-19 21:22:04,047 [INFO] iva.ssd.scripts.evaluate: Number of images in the validation dataset:	   630
# Number of images in the evaluation dataset: 630
#
# Producing predictions: 100%|████████████████████| 20/20 [00:07<00:00,  2.80it/s]
# Start multi-thread per-image matching
# Start to calculate AP for each class
# *******************************
# pedestrian    AP    0.853
#               mAP   0.853
# *******************************

# %% [markdown]
# ## 8. Visualize inferences <a class="anchor" id="head-8"></a>
# In this section, we run the tlt-infer tool to generate inferences on the trained models and visualize the results.

# %%
# Running inference for detection on n images
# !tlt-infer ssd -i $DATASET_DIR/images \
               -o $USER_EXPERIMENT_DIR/ssd_infer_images \
               -e $SPECS_DIR/ped_ssd_mobilenet_v2_retrain.txt \
               -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
               -l $USER_EXPERIMENT_DIR/ssd_infer_labels \
               -k $KEY
# Out:
# Using TensorFlow backend.
# 2020-05-19 21:22:52,570 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_retrain.txt
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 3, 320, 320)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 3, 322, 322)  0           Input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 16, 160, 160) 432         conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 16, 160, 160) 64          conv1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 16, 160, 160) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_pad (Ze (None, 16, 162, 162) 0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 16, 160, 160) 144         expanded_conv_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_bn (Bat (None, 16, 160, 160) 64          expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_relu (ReLU)       (None, 16, 160, 160) 0           expanded_conv_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 16, 160, 160) 256         expanded_conv_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project_bn (Batch (None, 16, 160, 160) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 48, 160, 160) 768         expanded_conv_project_bn[0][0]
# __________________________________________________________________________________________________
# block_1_expand_bn (BatchNormali (None, 48, 160, 160) 192         block_1_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 48, 160, 160) 0           block_1_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_pad (ZeroPadd (None, 48, 162, 162) 0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 48, 80, 80)   432         block_1_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_bn (BatchNorm (None, 48, 80, 80)   192         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_relu (ReLU)             (None, 48, 80, 80)   0           block_1_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 24, 80, 80)   1152        block_1_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_bn (BatchNormal (None, 24, 80, 80)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 72, 80, 80)   1728        block_1_project_bn[0][0]
# __________________________________________________________________________________________________
# block_2_expand_bn (BatchNormali (None, 72, 80, 80)   288         block_2_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 72, 80, 80)   0           block_2_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_pad (ZeroPadd (None, 72, 82, 82)   0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 72, 80, 80)   648         block_2_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_bn (BatchNorm (None, 72, 80, 80)   288         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_relu (ReLU)             (None, 72, 80, 80)   0           block_2_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 24, 80, 80)   1728        block_2_relu[0][0]
# __________________________________________________________________________________________________
# block_2_projected_inputs (Conv2 (None, 24, 80, 80)   576         block_1_project_bn[0][0]
# __________________________________________________________________________________________________
# block_2_project_bn (BatchNormal (None, 24, 80, 80)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 24, 80, 80)   0           block_2_projected_inputs[0][0]
#                                                                  block_2_project_bn[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 80, 80, 80)   1920        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_bn (BatchNormali (None, 80, 80, 80)   320         block_3_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 80, 80, 80)   0           block_3_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_pad (ZeroPadd (None, 80, 82, 82)   0           re_lu_4[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 80, 40, 40)   720         block_3_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_bn (BatchNorm (None, 80, 40, 40)   320         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_relu (ReLU)             (None, 80, 40, 40)   0           block_3_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 40, 40)   2560        block_3_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_bn (BatchNormal (None, 32, 40, 40)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 96, 40, 40)   3072        block_3_project_bn[0][0]
# __________________________________________________________________________________________________
# block_4_expand_bn (BatchNormali (None, 96, 40, 40)   384         block_4_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 96, 40, 40)   0           block_4_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_pad (ZeroPadd (None, 96, 42, 42)   0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 96, 40, 40)   864         block_4_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_bn (BatchNorm (None, 96, 40, 40)   384         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_relu (ReLU)             (None, 96, 40, 40)   0           block_4_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 16, 40, 40)   1536        block_4_relu[0][0]
# __________________________________________________________________________________________________
# block_4_projected_inputs (Conv2 (None, 16, 40, 40)   512         block_3_project_bn[0][0]
# __________________________________________________________________________________________________
# block_4_project_bn (BatchNormal (None, 16, 40, 40)   64          block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 16, 40, 40)   0           block_4_projected_inputs[0][0]
#                                                                  block_4_project_bn[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 72, 40, 40)   1152        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_bn (BatchNormali (None, 72, 40, 40)   288         block_5_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 72, 40, 40)   0           block_5_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_pad (ZeroPadd (None, 72, 42, 42)   0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 72, 40, 40)   648         block_5_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_bn (BatchNorm (None, 72, 40, 40)   288         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_relu (ReLU)             (None, 72, 40, 40)   0           block_5_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 24, 40, 40)   1728        block_5_relu[0][0]
# __________________________________________________________________________________________________
# block_5_projected_inputs (Conv2 (None, 24, 40, 40)   384         block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_project_bn (BatchNormal (None, 24, 40, 40)   96          block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 24, 40, 40)   0           block_5_projected_inputs[0][0]
#                                                                  block_5_project_bn[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 144, 40, 40)  3456        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_bn (BatchNormali (None, 144, 40, 40)  576         block_6_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 144, 40, 40)  0           block_6_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_pad (ZeroPadd (None, 144, 42, 42)  0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 144, 20, 20)  1296        block_6_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_bn (BatchNorm (None, 144, 20, 20)  576         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_relu (ReLU)             (None, 144, 20, 20)  0           block_6_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 64, 20, 20)   9216        block_6_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_bn (BatchNormal (None, 64, 20, 20)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 64, 20, 20)   4096        block_6_project_bn[0][0]
# __________________________________________________________________________________________________
# block_7_expand_bn (BatchNormali (None, 64, 20, 20)   256         block_7_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 64, 20, 20)   0           block_7_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_pad (ZeroPadd (None, 64, 22, 22)   0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 64, 20, 20)   576         block_7_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_bn (BatchNorm (None, 64, 20, 20)   256         block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_relu (ReLU)             (None, 64, 20, 20)   0           block_7_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 32, 20, 20)   2048        block_7_relu[0][0]
# __________________________________________________________________________________________________
# block_7_projected_inputs (Conv2 (None, 32, 20, 20)   2048        block_6_project_bn[0][0]
# __________________________________________________________________________________________________
# block_7_project_bn (BatchNormal (None, 32, 20, 20)   128         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 32, 20, 20)   0           block_7_projected_inputs[0][0]
#                                                                  block_7_project_bn[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 136, 20, 20)  4352        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_bn (BatchNormali (None, 136, 20, 20)  544         block_8_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 136, 20, 20)  0           block_8_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_pad (ZeroPadd (None, 136, 22, 22)  0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 136, 20, 20)  1224        block_8_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_bn (BatchNorm (None, 136, 20, 20)  544         block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_relu (ReLU)             (None, 136, 20, 20)  0           block_8_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 56, 20, 20)   7616        block_8_relu[0][0]
# __________________________________________________________________________________________________
# block_8_projected_inputs (Conv2 (None, 56, 20, 20)   1792        block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_project_bn (BatchNormal (None, 56, 20, 20)   224         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 56, 20, 20)   0           block_8_projected_inputs[0][0]
#                                                                  block_8_project_bn[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 120, 20, 20)  6720        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_bn (BatchNormali (None, 120, 20, 20)  480         block_9_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 120, 20, 20)  0           block_9_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_pad (ZeroPadd (None, 120, 22, 22)  0           re_lu_10[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 120, 20, 20)  1080        block_9_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_bn (BatchNorm (None, 120, 20, 20)  480         block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_relu (ReLU)             (None, 120, 20, 20)  0           block_9_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 64, 20, 20)   7680        block_9_relu[0][0]
# __________________________________________________________________________________________________
# block_9_projected_inputs (Conv2 (None, 64, 20, 20)   3584        block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_project_bn (BatchNormal (None, 64, 20, 20)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 64, 20, 20)   0           block_9_projected_inputs[0][0]
#                                                                  block_9_project_bn[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 192, 20, 20)  12288       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_bn (BatchNormal (None, 192, 20, 20)  768         block_10_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 192, 20, 20)  0           block_10_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_pad (ZeroPad (None, 192, 22, 22)  0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 192, 20, 20)  1728        block_10_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_bn (BatchNor (None, 192, 20, 20)  768         block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_relu (ReLU)            (None, 192, 20, 20)  0           block_10_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 96, 20, 20)   18432       block_10_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_bn (BatchNorma (None, 96, 20, 20)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 120, 20, 20)  11520       block_10_project_bn[0][0]
# __________________________________________________________________________________________________
# block_11_expand_bn (BatchNormal (None, 120, 20, 20)  480         block_11_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 120, 20, 20)  0           block_11_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_pad (ZeroPad (None, 120, 22, 22)  0           re_lu_12[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 120, 20, 20)  1080        block_11_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_bn (BatchNor (None, 120, 20, 20)  480         block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_relu (ReLU)            (None, 120, 20, 20)  0           block_11_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 88, 20, 20)   10560       block_11_relu[0][0]
# __________________________________________________________________________________________________
# block_11_projected_inputs (Conv (None, 88, 20, 20)   8448        block_10_project_bn[0][0]
# __________________________________________________________________________________________________
# block_11_project_bn (BatchNorma (None, 88, 20, 20)   352         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 88, 20, 20)   0           block_11_projected_inputs[0][0]
#                                                                  block_11_project_bn[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 80, 20, 20)   7040        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_bn (BatchNormal (None, 80, 20, 20)   320         block_12_expand[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 80, 20, 20)   0           block_12_expand_bn[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_pad (ZeroPad (None, 80, 22, 22)   0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 80, 20, 20)   720         block_12_depthwise_pad[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_bn (BatchNor (None, 80, 20, 20)   320         block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_relu (ReLU)            (None, 80, 20, 20)   0           block_12_depthwise_bn[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 96, 20, 20)   7680        block_12_relu[0][0]
# __________________________________________________________________________________________________
# block_12_projected_inputs (Conv (None, 96, 20, 20)   8448        block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_project_bn (BatchNorma (None, 96, 20, 20)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 96, 20, 20)   0           block_12_projected_inputs[0][0]
#                                                                  block_12_project_bn[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_0 (Conv (None, 64, 20, 20)   6208        block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_0 (ReLU (None, 64, 20, 20)   0           ssd_expand_block_1_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_conv_1 (Conv (None, 128, 10, 10)  73728       ssd_expand_block_1_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_bn_1 (BatchN (None, 128, 10, 10)  512         ssd_expand_block_1_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_1_relu_1 (ReLU (None, 128, 10, 10)  0           ssd_expand_block_1_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_0 (Conv (None, 64, 10, 10)   8256        ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_0 (ReLU (None, 64, 10, 10)   0           ssd_expand_block_2_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_conv_1 (Conv (None, 128, 5, 5)    73728       ssd_expand_block_2_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_bn_1 (BatchN (None, 128, 5, 5)    512         ssd_expand_block_2_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_2_relu_1 (ReLU (None, 128, 5, 5)    0           ssd_expand_block_2_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_0 (Conv (None, 64, 5, 5)     8256        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_0 (ReLU (None, 64, 5, 5)     0           ssd_expand_block_3_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_conv_1 (Conv (None, 128, 3, 3)    73728       ssd_expand_block_3_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_bn_1 (BatchN (None, 128, 3, 3)    512         ssd_expand_block_3_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_3_relu_1 (ReLU (None, 128, 3, 3)    0           ssd_expand_block_3_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_0 (Conv (None, 64, 3, 3)     8256        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_0 (ReLU (None, 64, 3, 3)     0           ssd_expand_block_4_conv_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_conv_1 (Conv (None, 128, 2, 2)    73728       ssd_expand_block_4_relu_0[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_bn_1 (BatchN (None, 128, 2, 2)    512         ssd_expand_block_4_conv_1[0][0]
# __________________________________________________________________________________________________
# ssd_expand_block_4_relu_1 (ReLU (None, 128, 2, 2)    0           ssd_expand_block_4_bn_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_0 (Conv2D)             (None, 6, 40, 40)    7782        re_lu_7[0][0]
# __________________________________________________________________________________________________
# ssd_conf_1 (Conv2D)             (None, 6, 20, 20)    5190        block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_conf_2 (Conv2D)             (None, 6, 10, 10)    6918        ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_3 (Conv2D)             (None, 6, 5, 5)      6918        ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_4 (Conv2D)             (None, 6, 3, 3)      6918        ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_conf_5 (Conv2D)             (None, 6, 2, 2)      6918        ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# permute_25 (Permute)            (None, 40, 40, 6)    0           ssd_conf_0[0][0]
# __________________________________________________________________________________________________
# permute_27 (Permute)            (None, 20, 20, 6)    0           ssd_conf_1[0][0]
# __________________________________________________________________________________________________
# permute_29 (Permute)            (None, 10, 10, 6)    0           ssd_conf_2[0][0]
# __________________________________________________________________________________________________
# permute_31 (Permute)            (None, 5, 5, 6)      0           ssd_conf_3[0][0]
# __________________________________________________________________________________________________
# permute_33 (Permute)            (None, 3, 3, 6)      0           ssd_conf_4[0][0]
# __________________________________________________________________________________________________
# permute_35 (Permute)            (None, 2, 2, 6)      0           ssd_conf_5[0][0]
# __________________________________________________________________________________________________
# ssd_loc_0 (Conv2D)              (None, 24, 40, 40)   31128       re_lu_7[0][0]
# __________________________________________________________________________________________________
# ssd_loc_1 (Conv2D)              (None, 24, 20, 20)   20760       block_12_add[0][0]
# __________________________________________________________________________________________________
# ssd_loc_2 (Conv2D)              (None, 24, 10, 10)   27672       ssd_expand_block_1_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_3 (Conv2D)              (None, 24, 5, 5)     27672       ssd_expand_block_2_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_4 (Conv2D)              (None, 24, 3, 3)     27672       ssd_expand_block_3_relu_1[0][0]
# __________________________________________________________________________________________________
# ssd_loc_5 (Conv2D)              (None, 24, 2, 2)     27672       ssd_expand_block_4_relu_1[0][0]
# __________________________________________________________________________________________________
# conf_reshape_0 (Reshape)        (None, 9600, 1, 1)   0           permute_25[0][0]
# __________________________________________________________________________________________________
# conf_reshape_1 (Reshape)        (None, 2400, 1, 1)   0           permute_27[0][0]
# __________________________________________________________________________________________________
# conf_reshape_2 (Reshape)        (None, 600, 1, 1)    0           permute_29[0][0]
# __________________________________________________________________________________________________
# conf_reshape_3 (Reshape)        (None, 150, 1, 1)    0           permute_31[0][0]
# __________________________________________________________________________________________________
# conf_reshape_4 (Reshape)        (None, 54, 1, 1)     0           permute_33[0][0]
# __________________________________________________________________________________________________
# conf_reshape_5 (Reshape)        (None, 24, 1, 1)     0           permute_35[0][0]
# __________________________________________________________________________________________________
# permute_26 (Permute)            (None, 40, 40, 24)   0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# permute_28 (Permute)            (None, 20, 20, 24)   0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# permute_30 (Permute)            (None, 10, 10, 24)   0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# permute_32 (Permute)            (None, 5, 5, 24)     0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# permute_34 (Permute)            (None, 3, 3, 24)     0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# permute_36 (Permute)            (None, 2, 2, 24)     0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_0 (AnchorBoxes)      (None, 1600, 6, 8)   0           ssd_loc_0[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_1 (AnchorBoxes)      (None, 400, 6, 8)    0           ssd_loc_1[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_2 (AnchorBoxes)      (None, 100, 6, 8)    0           ssd_loc_2[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_3 (AnchorBoxes)      (None, 25, 6, 8)     0           ssd_loc_3[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_4 (AnchorBoxes)      (None, 9, 6, 8)      0           ssd_loc_4[0][0]
# __________________________________________________________________________________________________
# ssd_anchor_5 (AnchorBoxes)      (None, 4, 6, 8)      0           ssd_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 12828, 1, 1)  0           conf_reshape_0[0][0]
#                                                                  conf_reshape_1[0][0]
#                                                                  conf_reshape_2[0][0]
#                                                                  conf_reshape_3[0][0]
#                                                                  conf_reshape_4[0][0]
#                                                                  conf_reshape_5[0][0]
# __________________________________________________________________________________________________
# loc_reshape_0 (Reshape)         (None, 9600, 1, 4)   0           permute_26[0][0]
# __________________________________________________________________________________________________
# loc_reshape_1 (Reshape)         (None, 2400, 1, 4)   0           permute_28[0][0]
# __________________________________________________________________________________________________
# loc_reshape_2 (Reshape)         (None, 600, 1, 4)    0           permute_30[0][0]
# __________________________________________________________________________________________________
# loc_reshape_3 (Reshape)         (None, 150, 1, 4)    0           permute_32[0][0]
# __________________________________________________________________________________________________
# loc_reshape_4 (Reshape)         (None, 54, 1, 4)     0           permute_34[0][0]
# __________________________________________________________________________________________________
# loc_reshape_5 (Reshape)         (None, 24, 1, 4)     0           permute_36[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_0 (Reshape)      (None, 9600, 1, 8)   0           ssd_anchor_0[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_1 (Reshape)      (None, 2400, 1, 8)   0           ssd_anchor_1[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_2 (Reshape)      (None, 600, 1, 8)    0           ssd_anchor_2[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_3 (Reshape)      (None, 150, 1, 8)    0           ssd_anchor_3[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_4 (Reshape)      (None, 54, 1, 8)     0           ssd_anchor_4[0][0]
# __________________________________________________________________________________________________
# anchor_reshape_5 (Reshape)      (None, 24, 1, 8)     0           ssd_anchor_5[0][0]
# __________________________________________________________________________________________________
# mbox_conf_sigmoid (Activation)  (None, 12828, 1, 1)  0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 12828, 1, 4)  0           loc_reshape_0[0][0]
#                                                                  loc_reshape_1[0][0]
#                                                                  loc_reshape_2[0][0]
#                                                                  loc_reshape_3[0][0]
#                                                                  loc_reshape_4[0][0]
#                                                                  loc_reshape_5[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 12828, 1, 8)  0           anchor_reshape_0[0][0]
#                                                                  anchor_reshape_1[0][0]
#                                                                  anchor_reshape_2[0][0]
#                                                                  anchor_reshape_3[0][0]
#                                                                  anchor_reshape_4[0][0]
#                                                                  anchor_reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12828, 1, 13) 0           mbox_conf_sigmoid[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# ssd_predictions (Reshape)       (None, 12828, 13)    0           concatenate_3[0][0]
# ==================================================================================================
# Total params: 711,292
# Trainable params: 704,044
# Non-trainable params: 7,248
# __________________________________________________________________________________________________
# 100%|███████████████████████████████████████| 4501/4501 [01:25<00:00, 52.34it/s]

# %% [markdown]
# The `tlt-infer` tool produces two outputs.
# 1. Overlain images in `$USER_EXPERIMENT_DIR/ssd_infer_images`
# 2. Frame by frame bbox labels in kitti format located in `$USER_EXPERIMENT_DIR/ssd_infer_labels`

# %%
# Simple grid visualizer
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

def visualize_images(image_dir, num_cols=4, num_images=10):
    output_path = os.path.join(os.environ['USER_EXPERIMENT_DIR'], image_dir)
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx / num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the sample images.
OUTPUT_PATH = 'ssd_infer_images' # relative path from $USER_EXPERIMENT_DIR.
COLS = 3 # number of columns in the visualizer grid.
IMAGES = 9 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 9. Deploy! <a class="anchor" id="head-9"></a>

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/export
# Export in FP32 mode. Change --data_type to fp16 for FP16 mode
# !tlt-export ssd -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt \
                -k $KEY \
                -o $USER_EXPERIMENT_DIR/export/ped_ssd_mobilenet_v2_epoch_$EPOCH.etlt \
                -e $SPECS_DIR/ped_ssd_mobilenet_v2_retrain.txt \
                --batch_size 1 \
                --data_type fp16

# Uncomment to export in INT8 mode (generate calibration cache file). \
# !tlt-export ssd -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/ssd_mobilenet_v2_epoch_$EPOCH.tlt  \
#                 -o $USER_EXPERIMENT_DIR/export/ped_ssd_mobilenet_v2_epoch_$EPOCH.etlt \
#                 -e $SPECS_DIR/ped_ssd_mobilenet_v2_retrain.txt \
#                 -k $KEY \
#                 --cal_image_dir  $USER_EXPERIMENT_DIR/data/testing/image_2 \
#                 --data_type int8 \
#                 --batch_size 1 \
#                 --batches 10 \
#                 --cal_cache_file $USER_EXPERIMENT_DIR/export/cal.bin  \
#                 --cal_data_file $USER_EXPERIMENT_DIR/export/cal.tensorfile
# Out:
# Using TensorFlow backend.
# 2020-05-19 21:26:16,396 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_retrain.txt
# 2020-05-19 21:26:19,050 [INFO] /usr/local/lib/python2.7/dist-packages/iva/ssd/utils/spec_loader.pyc: Merging specification from /repo/training/tlt/specs/ped_ssd_mobilenet_v2_retrain.txt
# NOTE: UFF has been tested with TensorFlow 1.14.0.
# WARNING: The version of TensorFlow installed on this system is not guaranteed to work with UFF.
# Warning: No conversion function registered for layer: NMS_TRT yet.
# Converting NMS as custom op: NMS_TRT
# Warning: No conversion function registered for layer: BatchTilePlugin_TRT yet.
# Converting FirstDimTile_5 as custom op: BatchTilePlugin_TRT
# Warning: No conversion function registered for layer: BatchTilePlugin_TRT yet.
# Converting FirstDimTile_4 as custom op: BatchTilePlugin_TRT
# Warning: No conversion function registered for layer: BatchTilePlugin_TRT yet.
# Converting FirstDimTile_3 as custom op: BatchTilePlugin_TRT
# Warning: No conversion function registered for layer: BatchTilePlugin_TRT yet.
# Converting FirstDimTile_2 as custom op: BatchTilePlugin_TRT
# Warning: No conversion function registered for layer: BatchTilePlugin_TRT yet.
# Converting FirstDimTile_1 as custom op: BatchTilePlugin_TRT
# Warning: No conversion function registered for layer: BatchTilePlugin_TRT yet.
# Converting FirstDimTile_0 as custom op: BatchTilePlugin_TRT
# DEBUG [/usr/lib/python2.7/dist-packages/uff/converters/tensorflow/converter.py:96] Marking ['NMS'] as outputs
# [TensorRT] INFO: Detected 1 inputs and 2 output network tensors.

# %% [markdown]
# `Note:` In this example, for ease of execution we restrict the number of calibrating batches to 10. TLT recommends the use of at least 10% of the training dataset for int8 calibration.

# %%
print('Exported model:')
print('------------')
# !ls -lh $USER_EXPERIMENT_DIR/export
# Out:
# Exported model:
# ------------
# total 3.3M
# -rw-r--r-- 1 root root 3.3M May 19 21:26 ped_ssd_mobilenet_v2_epoch_035.etlt

# %% [markdown]
# #### You can use this `.etlt` file directly in DeepStream or first create a `Tensor RT Engine` and then use the `engine` in DeepStream
